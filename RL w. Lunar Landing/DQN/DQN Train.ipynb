# %% [markdown]
# <a href="https://colab.research.google.com/github/TYH71/DELE_CA2_RL/blob/main/DQN/DQN%20Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DELE CA2 : Deep-Q Learning
#
# ## Motivation
#
# > This notebook is created to train a DQN agent on the LunarLander-v2 environtment.

# %%
# !pip3 install box2d-py
# Out:
# Collecting box2d-py
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 3.8 MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %%
# Import Libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import gym
from tqdm.notebook import tqdm 

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## Replay Buffer and Experience Replay
#
# > A buffer (temporary memory) of observations, rewards, and subsequent observations. The buffer is used to then train the Deep Learning model.
#
# The purpose of Experience Replay is to store past experiences and then using a random subset of these experiences to update the Q-network, rather than using just the single recent experience.
#
# A replay buffer contains a collection of experience (State, Action, Reward, New State). Normally, a replay buffer is store as a queue, where new buffer is added to the end so that it pushes the oldest experience out of it.

# %%
# The ReplayBuffer class is used to store experiences in a buffer of size N. 
# The buffer is used to sample a batch of experiences from the buffer to train the agent.
class ReplayBuffer:
    def __init__(self, size, input_shape):
        self.size = size
        self.counter = 0
        self.state_buffer = np.zeros((self.size, input_shape), dtype=np.float32)
        self.action_buffer = np.zeros(self.size, dtype=np.int32)
        self.reward_buffer = np.zeros(self.size, dtype=np.float32)
        self.new_state_buffer = np.zeros((self.size, input_shape), dtype=np.float32)
        self.terminal_buffer = np.zeros(self.size, dtype=np.bool_)

    # insert experience into the buffer
    def store_tuples(self, state, action, reward, new_state, done):
        idx = self.counter % self.size
        self.state_buffer[idx] = state
        self.action_buffer[idx] = action
        self.reward_buffer[idx] = reward
        self.new_state_buffer[idx] = new_state
        self.terminal_buffer[idx] = done
        self.counter += 1

    # Sample a batch of experiences from the buffer
    def sample_buffer(self, batch_size):
        max_buffer = min(self.counter, self.size)
        batch = np.random.choice(max_buffer, batch_size, replace=False)
        state_batch = self.state_buffer[batch]
        action_batch = self.action_buffer[batch]
        reward_batch = self.reward_buffer[batch]
        new_state_batch = self.new_state_buffer[batch]
        done_batch = self.terminal_buffer[batch]

        return state_batch, action_batch, reward_batch, new_state_batch, done_batch

# %% [markdown]
# ## Deep Q Network
#
# > Main idea of Deep Q Network is to use a neural network to map the state space to a Q-value for each action.
#
# A regular neural network with ReLU activation function is used to approximate the Q-function. The Q-function is a function of the state and action. The Q-function is approximated by a neural network with hidden layers. The output of the hidden layer is then used to approximate the Q-function. The Q Net is compiled with the Adam optimizer and mean squared error loss function.

# %%
# Function to Create DQN
def DeepQNetwork(lr, num_actions, input_dims, fc1, fc2):
    q_net = Sequential()
    q_net.add(Dense(fc1, input_dim=input_dims, activation='relu'))  # Takes in 8 observations as input
    q_net.add(Dense(fc2, activation='relu'))
    q_net.add(Dense(num_actions, activation=None))                  # Outputs a set of probabilities for each action
    q_net.compile(optimizer=Adam(learning_rate=lr), loss='mse')

    return q_net

# %% [markdown]
# # Agent
#
# ## Target Network
#
# > A target network is a copy of the estimated value function that is held fixed to serve as a stable target for some number of steps.
#
# When we alter the neural network parameters to $Q(s,a)$, it make alter $Q(s',a')$ and other states nearby, which is determined to make training very unstable.
#
# To make training more stabel, copying over the Q Net over to the target network and use it for the $Q(s', a')$.
#
# ## Policy
#
# The policy takes the highest Q-value of the current state and chooses the action with the highest Q-value. For the first few episodes, the agent will explore the environment by randomly choosing actions.
#
# $a \leftarrow argmax\ Q(s, a_s)$

# %%
# Agent Class
class Agent:
    def __init__(self, lr, discount_factor, num_actions, epsilon, batch_size, input_dims):
        self.action_space = [i for i in range(num_actions)]
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.batch_size = batch_size
        self.epsilon_decay = 0.001
        self.epsilon_final = 0.01
        self.update_rate = 120
        self.step_counter = 0
        self.buffer = ReplayBuffer(1000000, input_dims)
        self.q_net = DeepQNetwork(lr, num_actions, input_dims, 256, 256)
        self.q_target_net = DeepQNetwork(lr, num_actions, input_dims, 256, 256)

    def store_tuple(self, state, action, reward, new_state, done):
        '''
        Store the tuple (state, action, reward, new_state, done) in the buffer
        
        state: The state of the environment before the agent took the action
        action: The action the agent took
        reward: The reward received for performing action in state
        new_state: The state the agent is in after performing the action
        done: A boolean that indicates whether the episode has finished
        '''
        self.buffer.store_tuples(state, action, reward, new_state, done)

    def policy(self, observation):
        # Explores the env using random actions in the first few episodes
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_space)
        else:
            # Picks the Action with the Highest Q Value
            state = np.array([observation])
            actions = self.q_net(state)
            action = tf.math.argmax(actions, axis=1).numpy()[0]

        return action

    def train(self):
        '''
        Update the Q-network by training on a batch sampled from the replay buffer
        return: The agent's behaviour.
        '''
        # If the replay buffer is less than the batch size, don't train
        if self.buffer.counter < self.batch_size:
            return
        
        # This is the code that updates the target network. The target network is updated every 120 steps.
        if self.step_counter % self.update_rate == 0:
            self.q_target_net.set_weights(self.q_net.get_weights())

        # Sample a batch of experiences from the replay buffer
        state_batch, action_batch, reward_batch, new_state_batch, done_batch = \
            self.buffer.sample_buffer(self.batch_size)

        # Get the Q values for the current states
        q_predicted = self.q_net(state_batch)
        q_next = self.q_target_net(new_state_batch)
        q_max_next = tf.math.reduce_max(q_next, axis=1, keepdims=True).numpy()
        q_target = np.copy(q_predicted)

        # Calculating the target Q value for the current state.
        for idx in range(done_batch.shape[0]):
            target_q_val = reward_batch[idx]
            if not done_batch[idx]:
                target_q_val += self.discount_factor*q_max_next[idx]
            q_target[idx, action_batch[idx]] = target_q_val
        # Train the network over state and q target
        self.q_net.train_on_batch(state_batch, q_target)
        self.epsilon = self.epsilon - self.epsilon_decay if self.epsilon > self.epsilon_final else self.epsilon_final
        self.step_counter += 1

    # Main Function to train DQN
    def train_model(self, env, num_episodes, graph):
        scores, episodes, avg_scores, obj = [], [], [], []
        goal = 200
        f = 0
        txt = open("saved_networks.txt", "w")

        # This is the code that is used to train the agent. The agent is trained for a number of episodes.
        for i in tqdm(range(num_episodes)):
            done = False
            score = 0.0
            state = env.reset()
            while not done:
                action = self.policy(state)
                new_state, reward, done, _ = env.step(action)
                score += reward
                self.store_tuple(state, action, reward, new_state, done)
                state = new_state
                self.train()
            scores.append(score)
            obj.append(goal)
            episodes.append(i)
            avg_score = np.mean(scores[-100:])
            avg_scores.append(avg_score)
            print("Episode {0}/{1}, Score: {2} ({3}), AVG Score: {4}".format(i, num_episodes, score, self.epsilon,
                                                                             avg_score))
            
            # Saves the network's weights when avg score larger than 200 and score larger than 250
            if avg_score >= 200.0 and score >= 250:
                self.q_net.save(("saved_networks/dqn_model{0}".format(f)))
                self.q_net.save_weights(("saved_networks/dqn_model{0}/net_weights{0}.h5".format(f)))
                txt.write("Save {0} - Episode {1}/{2}, Score: {3} ({4}), AVG Score: {5}\n".format(f, i, num_episodes,
                                                                                                  score, self.epsilon,
                                                                                                  avg_score))
                f += 1
                print("Network saved")

        txt.close()

        ## Creating Train Learning Curve
        df = pd.DataFrame({'x': episodes, 'Score': scores, 'Average Score': avg_scores, 'Solved Requirement': obj})

        with plt.style.context('ggplot'):
            fig, ax = plt.subplots(figsize=(16, 9), tight_layout=True)
            ax.plot('x', 'Score', data=df, marker='', color='blue', linewidth=2, label='Score')
            ax.plot('x', 'Average Score', data=df, marker='', color='orange', linewidth=2, linestyle='dashed',
                    label='AverageScore')
            ax.plot('x', 'Solved Requirement', data=df, marker='', color='red', linewidth=2, linestyle='dashed',
                    label='Solved Requirement')
            ax.legend()
            fig.savefig('Train Learning Curve.png')

    # Main Function to test the trained DQN on a rendered Env
    def test(self, env, num_episodes, file_type, file, graph):
        # Loading the DQN weights from the saved model
        if file_type == 'tf':
            self.q_net = tf.keras.models.load_model(file)
        elif file_type == 'h5':
            self.train_model(env, 5, False)
            self.q_net.load_weights(file)
        
        self.epsilon = 0.0
        scores, episodes, avg_scores, obj = [], [], [], []
        goal = 200
        score = 0.0
        for i in range(num_episodes):
            state = env.reset()
            done = False
            episode_score = 0.0
            while not done:
                env.render()
                action = self.policy(state)
                new_state, reward, done, _ = env.step(action)
                episode_score += reward
                state = new_state
            score += episode_score
            scores.append(episode_score)
            obj.append(goal)
            episodes.append(i)
            avg_score = np.mean(scores[-100:])
            avg_scores.append(avg_score)

        ## Create Test Learning Curve        
        df = pd.DataFrame({'x': episodes, 'Score': scores, 'Average Score': avg_scores, 'Solved Requirement': obj})

        if graph:
            with plt.style.context('ggplot'):
                fig, ax = plt.subplots(figsize=(16, 9), tight_layout=True)
                ax.plot('x', 'Score', data=df, marker='', color='blue', linewidth=2, label='Score')
                ax.plot('x', 'Average Score', data=df, marker='', color='orange', linewidth=2, linestyle='dashed',
                        label='AverageScore')
                ax.plot('x', 'Solved Requirement', data=df, marker='', color='red', linewidth=2, linestyle='dashed',
                        label='Solved Requirement')
                ax.legend()
                fig.savefig('Test Learning Curve.png')
                plt.show()

        env.close()

# %%
# %%time
# Creating the environment and setting the specs for the environment.
env = gym.make("LunarLander-v2")
spec = gym.spec("LunarLander-v2")
num_episodes = 500
graph = True

# Creating an instance of the Agent class.
dqn_agent = Agent(lr=0.00075, discount_factor=0.99, num_actions=4, epsilon=1.0, batch_size=64, input_dims=8)

# Train DQN Agent
dqn_agent.train_model(env, num_episodes, graph)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
#
# INFO:tensorflow:Assets written to: saved_networks/dqn_model75/assets
# Network saved
# Episode 491/500, Score: 261.01747311572984 (0.01), AVG Score: 213.72070829236182
# INFO:tensorflow:Assets written to: saved_networks/dqn_model76/assets
# Network saved
# Episode 492/500, Score: 268.35166689590653 (0.01), AVG Score: 213.7983582045989
# INFO:tensorflow:Assets written to: saved_networks/dqn_model77/assets
# Network saved
# Episode 493/500, Score: -25.357403026236796 (0.01), AVG Score: 211.15669982995433
# Episode 494/500, Score: 259.9091704050071 (0.01), AVG Score: 210.95510752002716
# INFO:tensorflow:Assets written to: saved_networks/dqn_model78/assets
# Network saved
# Episode 495/500, Score: 247.86167710267094 (0.01), AVG Score: 211.00732780999428
# Episode 496/500, Score: 279.53704006051765 (0.01), AVG Score: 211.12731173843383
# INFO:tensorflow:Assets written to: saved_networks/dqn_model79/assets
# Network saved
# Episode 497/500, Score: 228.28934106210528 (0.01), AVG Score: 211.02340925826147
# Episode 498/500, Score: 266.1879602629991 (0.01), AVG Score: 211.77915325125178
# INFO:tensorflow:Assets written to: saved_networks/dqn_model80/assets
# Network saved
# Episode 499/500, Score: 246.06935108672096 (0.01), AVG Score: 214.31300487785856
# CPU times: user 47min 51s, sys: 3min 25s, total: 51min 17s
# Wall time: 45min 44s

# %%
# saving weights
! zip -r saved_networks.zip saved_networks
# Out:
#   adding: saved_networks/ (stored 0%)
#   adding: saved_networks/dqn_model10/ (stored 0%)
#   adding: saved_networks/dqn_model10/net_weights10.h5 (deflated 11%)
#   adding: saved_networks/dqn_model10/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model10/variables/ (stored 0%)
#   adding: saved_networks/dqn_model10/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model10/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model10/assets/ (stored 0%)
#   adding: saved_networks/dqn_model10/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model73/ (stored 0%)
#   adding: saved_networks/dqn_model73/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model73/net_weights73.h5 (deflated 11%)
#   adding: saved_networks/dqn_model73/variables/ (stored 0%)
#   adding: saved_networks/dqn_model73/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model73/variables/variables.data-00000-of-00001 (deflated 20%)
#   adding: saved_networks/dqn_model73/assets/ (stored 0%)
#   adding: saved_networks/dqn_model73/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model42/ (stored 0%)
#   adding: saved_networks/dqn_model42/net_weights42.h5 (deflated 11%)
#   adding: saved_networks/dqn_model42/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model42/variables/ (stored 0%)
#   adding: saved_networks/dqn_model42/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model42/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model42/assets/ (stored 0%)
#   adding: saved_networks/dqn_model42/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model61/ (stored 0%)
#   adding: saved_networks/dqn_model61/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model61/variables/ (stored 0%)
#   adding: saved_networks/dqn_model61/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model61/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model61/assets/ (stored 0%)
#   adding: saved_networks/dqn_model61/net_weights61.h5 (deflated 11%)
#   adding: saved_networks/dqn_model61/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model59/ (stored 0%)
#   adding: saved_networks/dqn_model59/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model59/variables/ (stored 0%)
#   adding: saved_networks/dqn_model59/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model59/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model59/assets/ (stored 0%)
#   adding: saved_networks/dqn_model59/net_weights59.h5 (deflated 11%)
#   adding: saved_networks/dqn_model59/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model15/ (stored 0%)
#   adding: saved_networks/dqn_model15/net_weights15.h5 (deflated 11%)
#   adding: saved_networks/dqn_model15/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model15/variables/ (stored 0%)
#   adding: saved_networks/dqn_model15/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model15/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model15/assets/ (stored 0%)
#   adding: saved_networks/dqn_model15/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model20/ (stored 0%)
#   adding: saved_networks/dqn_model20/net_weights20.h5 (deflated 11%)
#   adding: saved_networks/dqn_model20/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model20/variables/ (stored 0%)
#   adding: saved_networks/dqn_model20/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model20/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model20/assets/ (stored 0%)
#   adding: saved_networks/dqn_model20/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model36/ (stored 0%)
#   adding: saved_networks/dqn_model36/net_weights36.h5 (deflated 11%)
#   adding: saved_networks/dqn_model36/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model36/variables/ (stored 0%)
#   adding: saved_networks/dqn_model36/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model36/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model36/assets/ (stored 0%)
#   adding: saved_networks/dqn_model36/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model37/ (stored 0%)
#   adding: saved_networks/dqn_model37/net_weights37.h5 (deflated 11%)
#   adding: saved_networks/dqn_model37/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model37/variables/ (stored 0%)
#   adding: saved_networks/dqn_model37/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model37/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model37/assets/ (stored 0%)
#   adding: saved_networks/dqn_model37/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model3/ (stored 0%)
#   adding: saved_networks/dqn_model3/net_weights3.h5 (deflated 11%)
#   adding: saved_networks/dqn_model3/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model3/variables/ (stored 0%)
#   adding: saved_networks/dqn_model3/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model3/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model3/assets/ (stored 0%)
#   adding: saved_networks/dqn_model3/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model74/ (stored 0%)
#   adding: saved_networks/dqn_model74/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model74/variables/ (stored 0%)
#   adding: saved_networks/dqn_model74/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model74/variables/variables.data-00000-of-00001 (deflated 20%)
#   adding: saved_networks/dqn_model74/assets/ (stored 0%)
#   adding: saved_networks/dqn_model74/net_weights74.h5 (deflated 11%)
#   adding: saved_networks/dqn_model74/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model0/ (stored 0%)
#   adding: saved_networks/dqn_model0/net_weights0.h5 (deflated 11%)
#   adding: saved_networks/dqn_model0/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model0/variables/ (stored 0%)
#   adding: saved_networks/dqn_model0/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model0/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model0/assets/ (stored 0%)
#   adding: saved_networks/dqn_model0/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model55/ (stored 0%)
#   adding: saved_networks/dqn_model55/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model55/variables/ (stored 0%)
#   adding: saved_networks/dqn_model55/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model55/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model55/net_weights55.h5 (deflated 11%)
#   adding: saved_networks/dqn_model55/assets/ (stored 0%)
#   adding: saved_networks/dqn_model55/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model45/ (stored 0%)
#   adding: saved_networks/dqn_model45/net_weights45.h5 (deflated 11%)
#   adding: saved_networks/dqn_model45/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model45/variables/ (stored 0%)
#   adding: saved_networks/dqn_model45/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model45/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model45/assets/ (stored 0%)
#   adding: saved_networks/dqn_model45/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model56/ (stored 0%)
#   adding: saved_networks/dqn_model56/net_weights56.h5 (deflated 11%)
#   adding: saved_networks/dqn_model56/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model56/variables/ (stored 0%)
#   adding: saved_networks/dqn_model56/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model56/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model56/assets/ (stored 0%)
#   adding: saved_networks/dqn_model56/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model14/ (stored 0%)
#   adding: saved_networks/dqn_model14/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model14/variables/ (stored 0%)
#   adding: saved_networks/dqn_model14/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model14/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model14/net_weights14.h5 (deflated 11%)
#   adding: saved_networks/dqn_model14/assets/ (stored 0%)
#   adding: saved_networks/dqn_model14/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model41/ (stored 0%)
#   adding: saved_networks/dqn_model41/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model41/variables/ (stored 0%)
#   adding: saved_networks/dqn_model41/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model41/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model41/assets/ (stored 0%)
#   adding: saved_networks/dqn_model41/net_weights41.h5 (deflated 11%)
#   adding: saved_networks/dqn_model41/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model72/ (stored 0%)
#   adding: saved_networks/dqn_model72/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model72/variables/ (stored 0%)
#   adding: saved_networks/dqn_model72/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model72/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model72/assets/ (stored 0%)
#   adding: saved_networks/dqn_model72/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model72/net_weights72.h5 (deflated 11%)
#   adding: saved_networks/dqn_model71/ (stored 0%)
#   adding: saved_networks/dqn_model71/net_weights71.h5 (deflated 11%)
#   adding: saved_networks/dqn_model71/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model71/variables/ (stored 0%)
#   adding: saved_networks/dqn_model71/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model71/variables/variables.data-00000-of-00001 (deflated 20%)
#   adding: saved_networks/dqn_model71/assets/ (stored 0%)
#   adding: saved_networks/dqn_model71/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model11/ (stored 0%)
#   adding: saved_networks/dqn_model11/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model11/net_weights11.h5 (deflated 11%)
#   adding: saved_networks/dqn_model11/variables/ (stored 0%)
#   adding: saved_networks/dqn_model11/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model11/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model11/assets/ (stored 0%)
#   adding: saved_networks/dqn_model11/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model52/ (stored 0%)
#   adding: saved_networks/dqn_model52/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model52/variables/ (stored 0%)
#   adding: saved_networks/dqn_model52/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model52/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model52/assets/ (stored 0%)
#   adding: saved_networks/dqn_model52/net_weights52.h5 (deflated 11%)
#   adding: saved_networks/dqn_model52/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model8/ (stored 0%)
#   adding: saved_networks/dqn_model8/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model8/variables/ (stored 0%)
#   adding: saved_networks/dqn_model8/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model8/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model8/assets/ (stored 0%)
#   adding: saved_networks/dqn_model8/net_weights8.h5 (deflated 11%)
#   adding: saved_networks/dqn_model8/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model9/ (stored 0%)
#   adding: saved_networks/dqn_model9/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model9/variables/ (stored 0%)
#   adding: saved_networks/dqn_model9/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model9/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model9/assets/ (stored 0%)
#   adding: saved_networks/dqn_model9/net_weights9.h5 (deflated 11%)
#   adding: saved_networks/dqn_model9/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model13/ (stored 0%)
#   adding: saved_networks/dqn_model13/net_weights13.h5 (deflated 11%)
#   adding: saved_networks/dqn_model13/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model13/variables/ (stored 0%)
#   adding: saved_networks/dqn_model13/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model13/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model13/assets/ (stored 0%)
#   adding: saved_networks/dqn_model13/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model28/ (stored 0%)
#   adding: saved_networks/dqn_model28/net_weights28.h5 (deflated 11%)
#   adding: saved_networks/dqn_model28/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model28/variables/ (stored 0%)
#   adding: saved_networks/dqn_model28/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model28/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model28/assets/ (stored 0%)
#   adding: saved_networks/dqn_model28/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model58/ (stored 0%)
#   adding: saved_networks/dqn_model58/net_weights58.h5 (deflated 11%)
#   adding: saved_networks/dqn_model58/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model58/variables/ (stored 0%)
#   adding: saved_networks/dqn_model58/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model58/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model58/assets/ (stored 0%)
#   adding: saved_networks/dqn_model58/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model6/ (stored 0%)
#   adding: saved_networks/dqn_model6/net_weights6.h5 (deflated 11%)
#   adding: saved_networks/dqn_model6/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model6/variables/ (stored 0%)
#   adding: saved_networks/dqn_model6/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model6/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model6/assets/ (stored 0%)
#   adding: saved_networks/dqn_model6/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model35/ (stored 0%)
#   adding: saved_networks/dqn_model35/net_weights35.h5 (deflated 11%)
#   adding: saved_networks/dqn_model35/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model35/variables/ (stored 0%)
#   adding: saved_networks/dqn_model35/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model35/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model35/assets/ (stored 0%)
#   adding: saved_networks/dqn_model35/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model44/ (stored 0%)
#   adding: saved_networks/dqn_model44/net_weights44.h5 (deflated 11%)
#   adding: saved_networks/dqn_model44/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model44/variables/ (stored 0%)
#   adding: saved_networks/dqn_model44/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model44/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model44/assets/ (stored 0%)
#   adding: saved_networks/dqn_model44/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model23/ (stored 0%)
#   adding: saved_networks/dqn_model23/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model23/variables/ (stored 0%)
#   adding: saved_networks/dqn_model23/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model23/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model23/assets/ (stored 0%)
#   adding: saved_networks/dqn_model23/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model23/net_weights23.h5 (deflated 11%)
#   adding: saved_networks/dqn_model62/ (stored 0%)
#   adding: saved_networks/dqn_model62/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model62/variables/ (stored 0%)
#   adding: saved_networks/dqn_model62/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model62/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model62/assets/ (stored 0%)
#   adding: saved_networks/dqn_model62/net_weights62.h5 (deflated 11%)
#   adding: saved_networks/dqn_model62/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model38/ (stored 0%)
#   adding: saved_networks/dqn_model38/net_weights38.h5 (deflated 11%)
#   adding: saved_networks/dqn_model38/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model38/variables/ (stored 0%)
#   adding: saved_networks/dqn_model38/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model38/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model38/assets/ (stored 0%)
#   adding: saved_networks/dqn_model38/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model53/ (stored 0%)
#   adding: saved_networks/dqn_model53/net_weights53.h5 (deflated 11%)
#   adding: saved_networks/dqn_model53/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model53/variables/ (stored 0%)
#   adding: saved_networks/dqn_model53/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model53/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model53/assets/ (stored 0%)
#   adding: saved_networks/dqn_model53/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model75/ (stored 0%)
#   adding: saved_networks/dqn_model75/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model75/variables/ (stored 0%)
#   adding: saved_networks/dqn_model75/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model75/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model75/assets/ (stored 0%)
#   adding: saved_networks/dqn_model75/net_weights75.h5 (deflated 11%)
#   adding: saved_networks/dqn_model75/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model1/ (stored 0%)
#   adding: saved_networks/dqn_model1/net_weights1.h5 (deflated 11%)
#   adding: saved_networks/dqn_model1/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model1/variables/ (stored 0%)
#   adding: saved_networks/dqn_model1/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model1/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model1/assets/ (stored 0%)
#   adding: saved_networks/dqn_model1/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model51/ (stored 0%)
#   adding: saved_networks/dqn_model51/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model51/variables/ (stored 0%)
#   adding: saved_networks/dqn_model51/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model51/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model51/assets/ (stored 0%)
#   adding: saved_networks/dqn_model51/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model51/net_weights51.h5 (deflated 11%)
#   adding: saved_networks/dqn_model2/ (stored 0%)
#   adding: saved_networks/dqn_model2/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model2/variables/ (stored 0%)
#   adding: saved_networks/dqn_model2/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model2/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model2/assets/ (stored 0%)
#   adding: saved_networks/dqn_model2/net_weights2.h5 (deflated 11%)
#   adding: saved_networks/dqn_model2/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model70/ (stored 0%)
#   adding: saved_networks/dqn_model70/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model70/variables/ (stored 0%)
#   adding: saved_networks/dqn_model70/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model70/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model70/assets/ (stored 0%)
#   adding: saved_networks/dqn_model70/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model70/net_weights70.h5 (deflated 11%)
#   adding: saved_networks/dqn_model79/ (stored 0%)
#   adding: saved_networks/dqn_model79/net_weights79.h5 (deflated 11%)
#   adding: saved_networks/dqn_model79/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model79/variables/ (stored 0%)
#   adding: saved_networks/dqn_model79/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model79/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model79/assets/ (stored 0%)
#   adding: saved_networks/dqn_model79/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model39/ (stored 0%)
#   adding: saved_networks/dqn_model39/net_weights39.h5 (deflated 11%)
#   adding: saved_networks/dqn_model39/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model39/variables/ (stored 0%)
#   adding: saved_networks/dqn_model39/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model39/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model39/assets/ (stored 0%)
#   adding: saved_networks/dqn_model39/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model5/ (stored 0%)
#   adding: saved_networks/dqn_model5/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model5/variables/ (stored 0%)
#   adding: saved_networks/dqn_model5/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model5/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model5/assets/ (stored 0%)
#   adding: saved_networks/dqn_model5/net_weights5.h5 (deflated 11%)
#   adding: saved_networks/dqn_model5/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model18/ (stored 0%)
#   adding: saved_networks/dqn_model18/net_weights18.h5 (deflated 11%)
#   adding: saved_networks/dqn_model18/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model18/variables/ (stored 0%)
#   adding: saved_networks/dqn_model18/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model18/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model18/assets/ (stored 0%)
#   adding: saved_networks/dqn_model18/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model48/ (stored 0%)
#   adding: saved_networks/dqn_model48/net_weights48.h5 (deflated 11%)
#   adding: saved_networks/dqn_model48/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model48/variables/ (stored 0%)
#   adding: saved_networks/dqn_model48/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model48/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model48/assets/ (stored 0%)
#   adding: saved_networks/dqn_model48/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model65/ (stored 0%)
#   adding: saved_networks/dqn_model65/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model65/variables/ (stored 0%)
#   adding: saved_networks/dqn_model65/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model65/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model65/assets/ (stored 0%)
#   adding: saved_networks/dqn_model65/net_weights65.h5 (deflated 11%)
#   adding: saved_networks/dqn_model65/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model69/ (stored 0%)
#   adding: saved_networks/dqn_model69/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model69/variables/ (stored 0%)
#   adding: saved_networks/dqn_model69/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model69/variables/variables.data-00000-of-00001 (deflated 20%)
#   adding: saved_networks/dqn_model69/assets/ (stored 0%)
#   adding: saved_networks/dqn_model69/net_weights69.h5 (deflated 11%)
#   adding: saved_networks/dqn_model69/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model49/ (stored 0%)
#   adding: saved_networks/dqn_model49/net_weights49.h5 (deflated 11%)
#   adding: saved_networks/dqn_model49/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model49/variables/ (stored 0%)
#   adding: saved_networks/dqn_model49/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model49/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model49/assets/ (stored 0%)
#   adding: saved_networks/dqn_model49/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model32/ (stored 0%)
#   adding: saved_networks/dqn_model32/net_weights32.h5 (deflated 11%)
#   adding: saved_networks/dqn_model32/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model32/variables/ (stored 0%)
#   adding: saved_networks/dqn_model32/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model32/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model32/assets/ (stored 0%)
#   adding: saved_networks/dqn_model32/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model47/ (stored 0%)
#   adding: saved_networks/dqn_model47/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model47/net_weights47.h5 (deflated 11%)
#   adding: saved_networks/dqn_model47/variables/ (stored 0%)
#   adding: saved_networks/dqn_model47/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model47/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model47/assets/ (stored 0%)
#   adding: saved_networks/dqn_model47/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model64/ (stored 0%)
#   adding: saved_networks/dqn_model64/net_weights64.h5 (deflated 11%)
#   adding: saved_networks/dqn_model64/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model64/variables/ (stored 0%)
#   adding: saved_networks/dqn_model64/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model64/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model64/assets/ (stored 0%)
#   adding: saved_networks/dqn_model64/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model33/ (stored 0%)
#   adding: saved_networks/dqn_model33/net_weights33.h5 (deflated 11%)
#   adding: saved_networks/dqn_model33/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model33/variables/ (stored 0%)
#   adding: saved_networks/dqn_model33/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model33/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model33/assets/ (stored 0%)
#   adding: saved_networks/dqn_model33/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model67/ (stored 0%)
#   adding: saved_networks/dqn_model67/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model67/variables/ (stored 0%)
#   adding: saved_networks/dqn_model67/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model67/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model67/assets/ (stored 0%)
#   adding: saved_networks/dqn_model67/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model67/net_weights67.h5 (deflated 11%)
#   adding: saved_networks/dqn_model43/ (stored 0%)
#   adding: saved_networks/dqn_model43/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model43/variables/ (stored 0%)
#   adding: saved_networks/dqn_model43/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model43/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model43/assets/ (stored 0%)
#   adding: saved_networks/dqn_model43/net_weights43.h5 (deflated 11%)
#   adding: saved_networks/dqn_model43/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model21/ (stored 0%)
#   adding: saved_networks/dqn_model21/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model21/variables/ (stored 0%)
#   adding: saved_networks/dqn_model21/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model21/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model21/assets/ (stored 0%)
#   adding: saved_networks/dqn_model21/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model21/net_weights21.h5 (deflated 11%)
#   adding: saved_networks/dqn_model24/ (stored 0%)
#   adding: saved_networks/dqn_model24/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model24/variables/ (stored 0%)
#   adding: saved_networks/dqn_model24/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model24/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model24/assets/ (stored 0%)
#   adding: saved_networks/dqn_model24/net_weights24.h5 (deflated 11%)
#   adding: saved_networks/dqn_model24/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model22/ (stored 0%)
#   adding: saved_networks/dqn_model22/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model22/variables/ (stored 0%)
#   adding: saved_networks/dqn_model22/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model22/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model22/assets/ (stored 0%)
#   adding: saved_networks/dqn_model22/net_weights22.h5 (deflated 11%)
#   adding: saved_networks/dqn_model22/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model27/ (stored 0%)
#   adding: saved_networks/dqn_model27/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model27/variables/ (stored 0%)
#   adding: saved_networks/dqn_model27/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model27/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model27/net_weights27.h5 (deflated 11%)
#   adding: saved_networks/dqn_model27/assets/ (stored 0%)
#   adding: saved_networks/dqn_model27/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model17/ (stored 0%)
#   adding: saved_networks/dqn_model17/net_weights17.h5 (deflated 11%)
#   adding: saved_networks/dqn_model17/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model17/variables/ (stored 0%)
#   adding: saved_networks/dqn_model17/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model17/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model17/assets/ (stored 0%)
#   adding: saved_networks/dqn_model17/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model78/ (stored 0%)
#   adding: saved_networks/dqn_model78/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model78/variables/ (stored 0%)
#   adding: saved_networks/dqn_model78/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model78/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model78/assets/ (stored 0%)
#   adding: saved_networks/dqn_model78/net_weights78.h5 (deflated 11%)
#   adding: saved_networks/dqn_model78/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model16/ (stored 0%)
#   adding: saved_networks/dqn_model16/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model16/variables/ (stored 0%)
#   adding: saved_networks/dqn_model16/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model16/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model16/net_weights16.h5 (deflated 11%)
#   adding: saved_networks/dqn_model16/assets/ (stored 0%)
#   adding: saved_networks/dqn_model16/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model12/ (stored 0%)
#   adding: saved_networks/dqn_model12/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model12/variables/ (stored 0%)
#   adding: saved_networks/dqn_model12/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model12/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model12/assets/ (stored 0%)
#   adding: saved_networks/dqn_model12/net_weights12.h5 (deflated 11%)
#   adding: saved_networks/dqn_model12/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model26/ (stored 0%)
#   adding: saved_networks/dqn_model26/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model26/variables/ (stored 0%)
#   adding: saved_networks/dqn_model26/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model26/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model26/assets/ (stored 0%)
#   adding: saved_networks/dqn_model26/net_weights26.h5 (deflated 11%)
#   adding: saved_networks/dqn_model26/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model54/ (stored 0%)
#   adding: saved_networks/dqn_model54/net_weights54.h5 (deflated 11%)
#   adding: saved_networks/dqn_model54/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model54/variables/ (stored 0%)
#   adding: saved_networks/dqn_model54/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model54/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model54/assets/ (stored 0%)
#   adding: saved_networks/dqn_model54/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model40/ (stored 0%)
#   adding: saved_networks/dqn_model40/net_weights40.h5 (deflated 11%)
#   adding: saved_networks/dqn_model40/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model40/variables/ (stored 0%)
#   adding: saved_networks/dqn_model40/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model40/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model40/assets/ (stored 0%)
#   adding: saved_networks/dqn_model40/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model19/ (stored 0%)
#   adding: saved_networks/dqn_model19/net_weights19.h5 (deflated 11%)
#   adding: saved_networks/dqn_model19/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model19/variables/ (stored 0%)
#   adding: saved_networks/dqn_model19/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model19/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model19/assets/ (stored 0%)
#   adding: saved_networks/dqn_model19/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model77/ (stored 0%)
#   adding: saved_networks/dqn_model77/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model77/variables/ (stored 0%)
#   adding: saved_networks/dqn_model77/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model77/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model77/assets/ (stored 0%)
#   adding: saved_networks/dqn_model77/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model77/net_weights77.h5 (deflated 11%)
#   adding: saved_networks/dqn_model76/ (stored 0%)
#   adding: saved_networks/dqn_model76/net_weights76.h5 (deflated 11%)
#   adding: saved_networks/dqn_model76/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model76/variables/ (stored 0%)
#   adding: saved_networks/dqn_model76/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model76/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model76/assets/ (stored 0%)
#   adding: saved_networks/dqn_model76/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model4/ (stored 0%)
#   adding: saved_networks/dqn_model4/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model4/variables/ (stored 0%)
#   adding: saved_networks/dqn_model4/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model4/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model4/assets/ (stored 0%)
#   adding: saved_networks/dqn_model4/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model4/net_weights4.h5 (deflated 11%)
#   adding: saved_networks/dqn_model57/ (stored 0%)
#   adding: saved_networks/dqn_model57/net_weights57.h5 (deflated 11%)
#   adding: saved_networks/dqn_model57/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model57/variables/ (stored 0%)
#   adding: saved_networks/dqn_model57/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model57/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model57/assets/ (stored 0%)
#   adding: saved_networks/dqn_model57/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model31/ (stored 0%)
#   adding: saved_networks/dqn_model31/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model31/variables/ (stored 0%)
#   adding: saved_networks/dqn_model31/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model31/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model31/assets/ (stored 0%)
#   adding: saved_networks/dqn_model31/net_weights31.h5 (deflated 11%)
#   adding: saved_networks/dqn_model31/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model50/ (stored 0%)
#   adding: saved_networks/dqn_model50/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model50/net_weights50.h5 (deflated 11%)
#   adding: saved_networks/dqn_model50/variables/ (stored 0%)
#   adding: saved_networks/dqn_model50/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model50/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model50/assets/ (stored 0%)
#   adding: saved_networks/dqn_model50/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model46/ (stored 0%)
#   adding: saved_networks/dqn_model46/net_weights46.h5 (deflated 11%)
#   adding: saved_networks/dqn_model46/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model46/variables/ (stored 0%)
#   adding: saved_networks/dqn_model46/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model46/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model46/assets/ (stored 0%)
#   adding: saved_networks/dqn_model46/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model60/ (stored 0%)
#   adding: saved_networks/dqn_model60/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model60/net_weights60.h5 (deflated 11%)
#   adding: saved_networks/dqn_model60/variables/ (stored 0%)
#   adding: saved_networks/dqn_model60/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model60/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model60/assets/ (stored 0%)
#   adding: saved_networks/dqn_model60/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model68/ (stored 0%)
#   adding: saved_networks/dqn_model68/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model68/net_weights68.h5 (deflated 11%)
#   adding: saved_networks/dqn_model68/variables/ (stored 0%)
#   adding: saved_networks/dqn_model68/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model68/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model68/assets/ (stored 0%)
#   adding: saved_networks/dqn_model68/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model80/ (stored 0%)
#   adding: saved_networks/dqn_model80/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model80/variables/ (stored 0%)
#   adding: saved_networks/dqn_model80/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model80/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model80/assets/ (stored 0%)
#   adding: saved_networks/dqn_model80/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model80/net_weights80.h5 (deflated 11%)
#   adding: saved_networks/dqn_model30/ (stored 0%)
#   adding: saved_networks/dqn_model30/net_weights30.h5 (deflated 11%)
#   adding: saved_networks/dqn_model30/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model30/variables/ (stored 0%)
#   adding: saved_networks/dqn_model30/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model30/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model30/assets/ (stored 0%)
#   adding: saved_networks/dqn_model30/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model63/ (stored 0%)
#   adding: saved_networks/dqn_model63/net_weights63.h5 (deflated 11%)
#   adding: saved_networks/dqn_model63/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model63/variables/ (stored 0%)
#   adding: saved_networks/dqn_model63/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model63/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model63/assets/ (stored 0%)
#   adding: saved_networks/dqn_model63/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model25/ (stored 0%)
#   adding: saved_networks/dqn_model25/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model25/variables/ (stored 0%)
#   adding: saved_networks/dqn_model25/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model25/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model25/assets/ (stored 0%)
#   adding: saved_networks/dqn_model25/net_weights25.h5 (deflated 11%)
#   adding: saved_networks/dqn_model25/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model7/ (stored 0%)
#   adding: saved_networks/dqn_model7/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model7/variables/ (stored 0%)
#   adding: saved_networks/dqn_model7/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model7/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model7/assets/ (stored 0%)
#   adding: saved_networks/dqn_model7/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model7/net_weights7.h5 (deflated 11%)
#   adding: saved_networks/dqn_model34/ (stored 0%)
#   adding: saved_networks/dqn_model34/net_weights34.h5 (deflated 11%)
#   adding: saved_networks/dqn_model34/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model34/variables/ (stored 0%)
#   adding: saved_networks/dqn_model34/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model34/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model34/assets/ (stored 0%)
#   adding: saved_networks/dqn_model34/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model29/ (stored 0%)
#   adding: saved_networks/dqn_model29/saved_model.pb (deflated 88%)
#   adding: saved_networks/dqn_model29/variables/ (stored 0%)
#   adding: saved_networks/dqn_model29/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model29/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model29/assets/ (stored 0%)
#   adding: saved_networks/dqn_model29/net_weights29.h5 (deflated 11%)
#   adding: saved_networks/dqn_model29/keras_metadata.pb (deflated 87%)
#   adding: saved_networks/dqn_model66/ (stored 0%)
#   adding: saved_networks/dqn_model66/net_weights66.h5 (deflated 11%)
#   adding: saved_networks/dqn_model66/saved_model.pb (deflated 87%)
#   adding: saved_networks/dqn_model66/variables/ (stored 0%)
#   adding: saved_networks/dqn_model66/variables/variables.index (deflated 61%)
#   adding: saved_networks/dqn_model66/variables/variables.data-00000-of-00001 (deflated 19%)
#   adding: saved_networks/dqn_model66/assets/ (stored 0%)
#   adding: saved_networks/dqn_model66/keras_metadata.pb (deflated 87%)
