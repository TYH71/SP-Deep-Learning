# %% [markdown]
# # DELE CA2 : Double Dueling DQN
#
# ## Motivation
#
# > This notebook is created to train a Double Dueling DQN agent on the LunarLanderV2 environment.

# %%
# Import Libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gym
import os
import time
import datetime
import tensorflow.keras as keras
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %% [markdown]
# ## Replay Buffer and Experience Replay
#
# > A buffer (temporary memory) of observations, rewards, and subsequent observations. The buffer is used to then train the Deep Learning model.
#
# The purpose of Experience Replay is to store past experiences and then using a random subset of these experiences to update the Q-network, rather than using just the single recent experience.
#
# A replay buffer contains a collection of experience (State, Action, Reward, New State). Normally, a replay buffer is store as a queue, where new buffer is added to the end so that it pushes the oldest experience out of it.

# %%
# The ReplayBuffer class is used to store experiences in a buffer of size N. 
# The buffer is used to sample a batch of experiences from the buffer to train the agent.
class ReplayBuffer:
    def __init__(self, size, input_shape):
        self.size = size
        self.counter = 0
        self.state_buffer = np.zeros((self.size, *input_shape), dtype=np.float32)
        self.action_buffer = np.zeros(self.size, dtype=np.int32)
        self.reward_buffer = np.zeros(self.size, dtype=np.float32)
        self.new_state_buffer = np.zeros((self.size, *input_shape), dtype=np.float32)
        self.terminal_buffer = np.zeros(self.size, dtype=np.bool_)

    # insert experience into the buffer
    def store_tuples(self, state, action, reward, new_state, done):
        idx = self.counter % self.size
        self.state_buffer[idx] = state
        self.action_buffer[idx] = action
        self.reward_buffer[idx] = reward
        self.new_state_buffer[idx] = new_state
        self.terminal_buffer[idx] = done
        self.counter += 1

    # Sample a batch of experiences from the buffer
    def sample_buffer(self, batch_size):
        max_buffer = min(self.counter, self.size)
        batch = np.random.choice(max_buffer, batch_size, replace=False)
        state_batch = self.state_buffer[batch]
        action_batch = self.action_buffer[batch]
        reward_batch = self.reward_buffer[batch]
        new_state_batch = self.new_state_buffer[batch]
        done_batch = self.terminal_buffer[batch]

        return state_batch, action_batch, reward_batch, new_state_batch, done_batch

# %% [markdown]
# ## Double Dueling DQN
#
# The double dueling DQN is pretty similar to the Dueling DQN, there are two consisting estimator - the state value function, and the state dependent action advantage function.
#
# However there is an issue of a single DQN. The first time an agent receives a positive reward, it might continue making the same set action. A solution to solve this problem is to use two action value functions, in other words, two lookup tables. The agent uses one to update the other Q-value, providing an unbiased estimate of Q(s, a).
#
# $$ Q_1(S, A) \leftarrow Q_q(S, A) + \alpha(R + \gamma Q_2(S', argmax_aQ_1(S, a)) - Q_1(S, A)) $$

# %%
# The Dueling Double Deep Q Network is a neural network that has two separate heads. 
# One head is for the state value function V(s) and the other is for the advantage function A(s,a). 
# The advantage function is the difference between the state value function and the average of the
# advantage function. 
# The advantage function is used to reduce the overestimation of the Q function.
class DuelingDoubleDeepQNetwork(keras.Model):
    def __init__(self, num_actions, fc1, fc2):
        super(DuelingDoubleDeepQNetwork, self).__init__()
        self.dense1 = Dense(fc1, activation='relu')
        self.dense2 = Dense(fc2, activation='relu')
        self.V = Dense(1, activation=None)
        self.A = Dense(num_actions, activation=None)

    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        V = self.V(x)
        A = self.A(x)
        avg_A = tf.math.reduce_mean(A, axis=1, keepdims=True)
        Q = (V + (A - avg_A))

        return Q, A

# %% [markdown]
# # Agent
#
# ## Target Network
#
# > A target network is a copy of the estimated value function that is held fixed to serve as a stable target for some number of steps.
#
# When we alter the neural network parameters to $Q(s,a)$, it make alter $Q(s',a')$ and other states nearby, which is determined to make training very unstable.
#
# To make training more stabel, copying over the Q Net over to the target network and use it for the $Q(s', a')$.
#
# ## Policy
#
# The policy takes the highest Q-value of the current state and chooses the action with the highest Q-value. For the first few episodes, the agent will explore the environment by randomly choosing actions.
#
# $a \leftarrow argmax\ Q(s, a_s)$

# %%
# Agent Class
class Agent:
    def __init__(self, lr, discount_factor, num_actions, epsilon, batch_size, input_dim):
        self.action_space = [i for i in range(num_actions)]
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.batch_size = batch_size
        self.epsilon_decay = 0.001
        self.epsilon_final = 0.01
        self.update_rate = 120
        self.step_counter = 0
        self.buffer = ReplayBuffer(100000, input_dim)
        self.q_net = DuelingDoubleDeepQNetwork(num_actions, 128, 128)
        self.q_target_net = DuelingDoubleDeepQNetwork(num_actions, 128, 128)
        self.q_net.compile(optimizer=Adam(learning_rate=lr), loss='mse')
        self.q_target_net.compile(optimizer=Adam(learning_rate=lr), loss='mse')

    def store_tuple(self, state, action, reward, new_state, done):
        '''
        Store the tuple of the experience in the buffer.
        
        state: The state of the environment before the agent took the action
        action: The action taken by the agent in the current state
        reward: The reward received for performing action in state
        new_state: The state the agent is in after performing the action
        done: A boolean that indicates whether the episode has finished
        '''
        self.buffer.store_tuples(state, action, reward, new_state, done)

    def policy(self, observation):
        # Explores the env using random actions in the first few episodes
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_space)
        else:
            # Picks the action with the highest Q value
            state = np.array([observation])
            _, actions = self.q_net(state)
            action = tf.math.argmax(actions, axis=1).numpy()[0]

        return action

    def train(self):
        '''
        Update the Q-network by training on a batch sampled from the replay buffer
        return: The agent's behaviour.
        '''
        # If the replay buffer is less than the batch size, don't train
        if self.buffer.counter < self.batch_size:
            return
        
        # This is the code that updates the target network. The target network is updated every 120 steps.
        if self.step_counter % self.update_rate == 0:
            self.q_target_net.set_weights(self.q_net.get_weights())

        # Sample a batch of experiences from the replay buffer
        state_batch, action_batch, reward_batch, new_state_batch, done_batch = \
            self.buffer.sample_buffer(self.batch_size)

        # Get the Q values for the next state and the action taken
        q_predicted, _ = self.q_net(state_batch)
        q_next, _ = self.q_target_net(new_state_batch)
        q_target = q_predicted.numpy()
        _, actions = self.q_net(new_state_batch)
        max_actions = tf.math.argmax(actions, axis=1)

        for idx in range(done_batch.shape[0]):
            q_target[idx, action_batch[idx]] = reward_batch[idx] + self.discount_factor*q_next[idx, max_actions[idx]] *\
                                               (1-int(done_batch[idx]))

        # Train the network over state and q target
        self.q_net.train_on_batch(state_batch, q_target)
        self.epsilon = self.epsilon - self.epsilon_decay if self.epsilon > self.epsilon_final else self.epsilon_final
        self.step_counter += 1

    # Main Function to train D3QN
    def train_model(self, env, num_episodes, graph):
        scores, episodes, avg_scores, obj = [], [], [], []
        goal = 200
        f = 0
        txt = open("saved_networks.txt", "w")

        # This is the code that is used to train the agent. The agent is trained for a number of episodes.
        for i in range(num_episodes):
            done = False
            score = 0.0
            state = env.reset()
            while not done:
                action = self.policy(state)
                new_state, reward, done, _ = env.step(action)
                score += reward
                self.store_tuple(state, action, reward, new_state, done)
                state = new_state
                self.train()
            scores.append(score)
            obj.append(goal)
            episodes.append(i)
            avg_score = np.mean(scores[-100:])
            avg_scores.append(avg_score)
            print("Episode {0}/{1}, Score: {2} ({3}), AVG Score: {4}".format(i, num_episodes, score, self.epsilon,
                                                                             avg_score))
            
            # Saves the network's weights when avg score larger than 200 and score larger than 250
            if avg_score >= 200.0 and score >= 250:
                self.q_net.save(("saved_networks/d3qn_model{0}".format(f)))
                self.q_net.save_weights(("saved_networks/d3qn_model{0}/net_weights{0}.h5".format(f)))
                txt.write("Save {0} - Episode {1}/{2}, Score: {3} ({4}), AVG Score: {5}\n".format(f, i, num_episodes,
                                                                                                  score, self.epsilon,
                                                                                                  avg_score))
                f += 1
                print("Network saved")

        txt.close()
        
        
        # Creating Training Learning Curve
        if graph:
            df = pd.DataFrame({'x': episodes, 'Score': scores, 'Average Score': avg_scores, 'Solved Requirement': obj})

            plt.plot('x', 'Score', data=df, marker='', color='blue', linewidth=2, label='Score')
            plt.plot('x', 'Average Score', data=df, marker='', color='orange', linewidth=2, linestyle='dashed',
                     label='AverageScore')
            plt.plot('x', 'Solved Requirement', data=df, marker='', color='red', linewidth=2, linestyle='dashed',
                     label='Solved Requirement')
            plt.legend()
            plt.savefig('LunarLander_Train.png')

    # Main Function to test the trained D3QN on a rendered env
    def test(self, env, num_episodes, file_type, file, graph):
        # Loading the D3QN weights from the saved model
        if file_type == 'tf':
            self.q_net = tf.keras.models.load_model(file)
        elif file_type == 'h5':
            self.train_model(env, 5, False)
            self.q_net.load_weights(file)
        self.epsilon = 0.0
        scores, episodes, avg_scores, obj = [], [], [], []
        goal = 200
        score = 0.0
        for i in range(num_episodes):
            state = env.reset()
            done = False
            episode_score = 0.0
            while not done:
                env.render()
                action = self.policy(state)
                new_state, reward, done, _ = env.step(action)
                episode_score += reward
                state = new_state
            score += episode_score
            scores.append(episode_score)
            obj.append(goal)
            episodes.append(i)
            avg_score = np.mean(scores[-100:])
            avg_scores.append(avg_score)

        # Create Test Learning Curve
        if graph:
            df = pd.DataFrame({'x': episodes, 'Score': scores, 'Average Score': avg_scores, 'Solved Requirement': obj})

            plt.plot('x', 'Score', data=df, marker='', color='blue', linewidth=2, label='Score')
            plt.plot('x', 'Average Score', data=df, marker='', color='orange', linewidth=2, linestyle='dashed',
                     label='AverageScore')
            plt.plot('x', 'Solved Requirement', data=df, marker='', color='red', linewidth=2, linestyle='dashed',
                     label='Solved Requirement')
            plt.legend()
            plt.savefig('LunarLander_Test.png')

        env.close()

# %%
# Creating the environment and setting the specs for the environment
env = gym.make("LunarLander-v2")
spec = gym.spec("LunarLander-v2")
num_episodes = 500
graph = True

# creating instance of the Agenet Class
dqn_agent = Agent(lr=0.00075, discount_factor=0.99, num_actions=4, epsilon=1.0, batch_size=64, input_dim=[8])

# Traing D3QN Agent
dqn_agent.train_model(env, num_episodes, graph)
# Out:
# Episode 0/500, Score: -87.93906949068453 (0.959), AVG Score: -87.93906949068453
# Episode 1/500, Score: -165.08025012545187 (0.8329999999999999), AVG Score: -126.50965980806819
# Episode 2/500, Score: -262.06423386637323 (0.7339999999999998), AVG Score: -171.6945178275032
# Episode 3/500, Score: -269.20826188190495 (0.6169999999999997), AVG Score: -196.07295384110364
# Episode 4/500, Score: -95.7877298464324 (0.5039999999999996), AVG Score: -176.0159090421694
# Episode 5/500, Score: -122.6813847991598 (0.39099999999999946), AVG Score: -167.12682166833446
# Episode 6/500, Score: -307.2186044197391 (0.2269999999999993), AVG Score: -187.13993348996368
# Episode 7/500, Score: -73.9086704951373 (0.01), AVG Score: -172.9860256156104
# Episode 8/500, Score: -82.24430241837247 (0.01), AVG Score: -162.9036119270284
# Episode 9/500, Score: -342.3441339649987 (0.01), AVG Score: -180.84766413082542
# Episode 10/500, Score: -269.5671220238703 (0.01), AVG Score: -188.9130693938295
# Episode 11/500, Score: -90.72334371773998 (0.01), AVG Score: -180.73059225415537
# Episode 12/500, Score: -143.817959615456 (0.01), AVG Score: -177.89115897425543
# Episode 13/500, Score: -71.02607006534792 (0.01), AVG Score: -170.2579383379049
# Episode 14/500, Score: -89.89440062769296 (0.01), AVG Score: -164.9003691572241
# Episode 15/500, Score: -148.34938960150023 (0.01), AVG Score: -163.86593293499135
# Episode 16/500, Score: -168.8758749850757 (0.01), AVG Score: -164.16063540852574
# Episode 17/500, Score: -138.03074081115514 (0.01), AVG Score: -162.7089745975607
# Episode 18/500, Score: -133.35900467242982 (0.01), AVG Score: -161.1642393383433
# Episode 19/500, Score: -163.40807658648419 (0.01), AVG Score: -161.27643120075032
# Episode 20/500, Score: -229.76571448102146 (0.01), AVG Score: -164.537825642668
# Episode 21/500, Score: -162.03373039386656 (0.01), AVG Score: -164.42400313135886
# Episode 22/500, Score: -201.19862500046864 (0.01), AVG Score: -166.02289973436365
# Episode 23/500, Score: -77.59437956532388 (0.01), AVG Score: -162.33837806065364
# Episode 24/500, Score: -28.425341314515748 (0.01), AVG Score: -156.98185659080812
# Episode 25/500, Score: -38.78261931677424 (0.01), AVG Score: -152.43573208026834
# Episode 26/500, Score: -3.1672033780315783 (0.01), AVG Score: -146.9072680542596
# Episode 27/500, Score: -39.46984112258327 (0.01), AVG Score: -143.070217092414
# Episode 28/500, Score: -271.7793071203105 (0.01), AVG Score: -147.50846157613455
# Episode 29/500, Score: -44.5219337553617 (0.01), AVG Score: -144.0755773154421
# Episode 30/500, Score: 13.896448383380108 (0.01), AVG Score: -138.9797055187059
# Episode 31/500, Score: -48.96140137264443 (0.01), AVG Score: -136.1666335141415
# Episode 32/500, Score: -37.61260236979909 (0.01), AVG Score: -133.1801477218887
# Episode 33/500, Score: 2.526837046712777 (0.01), AVG Score: -129.18876581692982
# Episode 34/500, Score: -35.54469151480255 (0.01), AVG Score: -126.51322083686902
# Episode 35/500, Score: -15.486661534053194 (0.01), AVG Score: -123.42914974512415
# Episode 36/500, Score: -333.1572481355002 (0.01), AVG Score: -129.09747672864785
# Episode 37/500, Score: -46.06770528288404 (0.01), AVG Score: -126.912482743233
# Episode 38/500, Score: 2.1384591450668635 (0.01), AVG Score: -123.6034842332766
# Episode 39/500, Score: -33.9034071955695 (0.01), AVG Score: -121.36098230733394
# Episode 40/500, Score: -79.7953143080437 (0.01), AVG Score: -120.34718552686346
# Episode 41/500, Score: -64.29082174983024 (0.01), AVG Score: -119.01251019883887
# Episode 42/500, Score: -86.96566658695546 (0.01), AVG Score: -118.26723476600436
# Episode 43/500, Score: -84.14917330728255 (0.01), AVG Score: -117.49182427830614
# Episode 44/500, Score: -19.26717430927402 (0.01), AVG Score: -115.30905427899431
# Episode 45/500, Score: -81.5058753801319 (0.01), AVG Score: -114.57420256380166
# Episode 46/500, Score: -67.67677681336588 (0.01), AVG Score: -113.57638499464345
# Episode 47/500, Score: -43.28421950054203 (0.01), AVG Score: -112.111964880183
# Episode 48/500, Score: -63.300868716019025 (0.01), AVG Score: -111.11582006050618
# Episode 49/500, Score: -93.00784138242417 (0.01), AVG Score: -110.75366048694454
# Episode 50/500, Score: -227.71429627925278 (0.01), AVG Score: -113.04700628679373
# Episode 51/500, Score: -176.73987256323335 (0.01), AVG Score: -114.27186909980219
# Episode 52/500, Score: -172.45557712878477 (0.01), AVG Score: -115.36967491166979
# Episode 53/500, Score: -145.05452851023958 (0.01), AVG Score: -115.91939442275442
# Episode 54/500, Score: -249.59911765378487 (0.01), AVG Score: -118.34993484513679
# Episode 55/500, Score: -190.84832291203878 (0.01), AVG Score: -119.64454891776002
# Episode 56/500, Score: -170.51214106966876 (0.01), AVG Score: -120.53696281516191
# Episode 57/500, Score: -112.90470867877103 (0.01), AVG Score: -120.40537222660346
# Episode 58/500, Score: -92.54828524135326 (0.01), AVG Score: -119.9332182099043
# Episode 59/500, Score: -63.31823746958254 (0.01), AVG Score: -118.9896351975656
# Episode 60/500, Score: -143.61824904498812 (0.01), AVG Score: -119.39338296555614
# Episode 61/500, Score: -72.24843366726293 (0.01), AVG Score: -118.63298055751916
# Episode 62/500, Score: -60.29037790706781 (0.01), AVG Score: -117.70690749957548
# Episode 63/500, Score: -42.0651382035914 (0.01), AVG Score: -116.52500485432573
# Episode 64/500, Score: -10.93405889022466 (0.01), AVG Score: -114.90052876257033
# Episode 65/500, Score: 8.195773416180067 (0.01), AVG Score: -113.03543327501352
# Episode 66/500, Score: -75.8312729185226 (0.01), AVG Score: -112.4801472995435
# Episode 67/500, Score: -62.6645629597467 (0.01), AVG Score: -111.74756517689944
# Episode 68/500, Score: -51.51030703726805 (0.01), AVG Score: -110.87456143574536
# Episode 69/500, Score: -53.47004162488123 (0.01), AVG Score: -110.05449686701873
# Episode 70/500, Score: -60.639911247408044 (0.01), AVG Score: -109.35851678786929
# Episode 71/500, Score: -20.253680044529315 (0.01), AVG Score: -108.12094961087843
# Episode 72/500, Score: -20.494669366713275 (0.01), AVG Score: -106.92058960753371
# Episode 73/500, Score: -8.052630802146407 (0.01), AVG Score: -105.58453611016361
# Episode 74/500, Score: -55.2191579979968 (0.01), AVG Score: -104.91299773533473
# Episode 75/500, Score: -79.20216227699743 (0.01), AVG Score: -104.57469726877764
# Episode 76/500, Score: -47.41423839754358 (0.01), AVG Score: -103.8323536470733
# Episode 77/500, Score: -92.52545607714785 (0.01), AVG Score: -103.68739342181786
# Episode 78/500, Score: -194.497552898176 (0.01), AVG Score: -104.83688911139201
# Episode 79/500, Score: -67.63711912840013 (0.01), AVG Score: -104.3718919866046
# Episode 80/500, Score: -33.6566569053982 (0.01), AVG Score: -103.49886439300946
# Episode 81/500, Score: -61.838680049514934 (0.01), AVG Score: -102.99081336443025
# Episode 82/500, Score: -157.92664394726057 (0.01), AVG Score: -103.65269084133183
# Episode 83/500, Score: -119.30716382838254 (0.01), AVG Score: -103.8390536149872
# Episode 84/500, Score: -114.61522724208004 (0.01), AVG Score: -103.96583212824711
# Episode 85/500, Score: -43.61143461572895 (0.01), AVG Score: -103.2640368083341
# Episode 86/500, Score: -61.31120674486142 (0.01), AVG Score: -102.78182037082293
# Episode 87/500, Score: -8.453086036025647 (0.01), AVG Score: -101.70990293520025
# Episode 88/500, Score: -59.388803167881264 (0.01), AVG Score: -101.23438496028655
# Episode 89/500, Score: -59.22114199396822 (0.01), AVG Score: -100.76757114954968
# Episode 90/500, Score: -63.56930238794568 (0.01), AVG Score: -100.35879896535623
# Episode 91/500, Score: -4.638563848629018 (0.01), AVG Score: -99.31836162713091
# Episode 92/500, Score: -1.5730521788118559 (0.01), AVG Score: -98.2673367943533
# Episode 93/500, Score: -4.626715636593854 (0.01), AVG Score: -97.27115997352607
# Episode 94/500, Score: -154.90866753113116 (0.01), AVG Score: -97.8778705793956
# Episode 95/500, Score: -31.282558863397426 (0.01), AVG Score: -97.18416941568728
# Episode 96/500, Score: -272.17626103277473 (0.01), AVG Score: -98.98821159730674
# Episode 97/500, Score: 10.445049842618984 (0.01), AVG Score: -97.87154566424627
# Episode 98/500, Score: 20.33940420379337 (0.01), AVG Score: -96.67749566557922
# Episode 99/500, Score: -37.92856640109791 (0.01), AVG Score: -96.0900063729344
# Episode 100/500, Score: -44.19736948337573 (0.01), AVG Score: -95.65258937286133
# Episode 101/500, Score: -1.8649505877908954 (0.01), AVG Score: -94.02043637748473
# Episode 102/500, Score: 6.586565973119975 (0.01), AVG Score: -91.33392837908976
# Episode 103/500, Score: -221.05382094880906 (0.01), AVG Score: -90.85238396975882
# Episode 104/500, Score: -58.5145054366857 (0.01), AVG Score: -90.47965172566136
# Episode 105/500, Score: -76.49499775722511 (0.01), AVG Score: -90.01778785524199
# Episode 106/500, Score: -67.23585453547462 (0.01), AVG Score: -87.61796035639937
# Episode 107/500, Score: -23.00944036012271 (0.01), AVG Score: -87.1089680550492
# Episode 108/500, Score: 208.04616419716672 (0.01), AVG Score: -84.20606338889382
# Episode 109/500, Score: -59.85041761933304 (0.01), AVG Score: -81.38112622543717
# Episode 110/500, Score: -61.14240291975999 (0.01), AVG Score: -79.29687903439604
# Episode 111/500, Score: -91.80202753109658 (0.01), AVG Score: -79.30766587252961
# Episode 112/500, Score: 11.463803153512053 (0.01), AVG Score: -77.75484824483992
# Episode 113/500, Score: -7.944040215372211 (0.01), AVG Score: -77.12402794634016
# Episode 114/500, Score: 193.1792918976758 (0.01), AVG Score: -74.29329102108647
# Episode 115/500, Score: 187.41402641178007 (0.01), AVG Score: -70.93565686095367
# Episode 116/500, Score: -56.13462462387583 (0.01), AVG Score: -69.80824435734166
# Episode 117/500, Score: -64.43162097486281 (0.01), AVG Score: -69.07225315897875
# Episode 118/500, Score: -33.51973324594117 (0.01), AVG Score: -68.07386044471386
# Episode 119/500, Score: -56.44815874239519 (0.01), AVG Score: -67.00426126627298
# Episode 120/500, Score: -3.154925551670824 (0.01), AVG Score: -64.73815337697948
# Episode 121/500, Score: -50.07726634064598 (0.01), AVG Score: -63.61858873644727
# Episode 122/500, Score: -25.54833677935514 (0.01), AVG Score: -61.86208585423615
# Episode 123/500, Score: -35.5429742233387 (0.01), AVG Score: -61.44157180081629
# Episode 124/500, Score: 2.3069750749489835 (0.01), AVG Score: -61.13424863692164
# Episode 125/500, Score: 5.5154030180085245 (0.01), AVG Score: -60.691268413573816
# Episode 126/500, Score: -35.83223342496078 (0.01), AVG Score: -61.017918714043105
# Episode 127/500, Score: -22.243876232268736 (0.01), AVG Score: -60.84565906513996
# Episode 128/500, Score: -161.26323143418512 (0.01), AVG Score: -59.74049830827872
# Episode 129/500, Score: -67.78557335073329 (0.01), AVG Score: -59.97313470423242
# Episode 130/500, Score: -35.4449740067539 (0.01), AVG Score: -60.46654892813377
# Episode 131/500, Score: -12.069601902047069 (0.01), AVG Score: -60.09763093342779
# Episode 132/500, Score: -9.085717702352625 (0.01), AVG Score: -59.812362086753325
# Episode 133/500, Score: 0.011770447601878953 (0.01), AVG Score: -59.83751275274443
# Episode 134/500, Score: -50.37551746597701 (0.01), AVG Score: -59.98582101225618
# Episode 135/500, Score: -116.79276646096878 (0.01), AVG Score: -60.99888206152534
# Episode 136/500, Score: 27.879646206836057 (0.01), AVG Score: -57.38851311810198
# Episode 137/500, Score: 11.792694115798355 (0.01), AVG Score: -56.809909124115144
# Episode 138/500, Score: 148.34335522647905 (0.01), AVG Score: -55.34786016330103
# Episode 139/500, Score: 231.2003272904506 (0.01), AVG Score: -52.696822818440836
# Episode 140/500, Score: 39.74524007188277 (0.01), AVG Score: -51.50141727464156
# Episode 141/500, Score: 214.07814188287068 (0.01), AVG Score: -48.71772763831454
# Episode 142/500, Score: 135.10355178182226 (0.01), AVG Score: -46.49703545462677
# Episode 143/500, Score: -112.36253313444337 (0.01), AVG Score: -46.77916905289837
# Episode 144/500, Score: 147.57527107521355 (0.01), AVG Score: -45.110744599053504
# Episode 145/500, Score: -14.928705374369637 (0.01), AVG Score: -44.444972898995886
# Episode 146/500, Score: 224.62418857362613 (0.01), AVG Score: -41.52196324512595
# Episode 147/500, Score: 244.18451352266663 (0.01), AVG Score: -38.64727591489387
# Episode 148/500, Score: 240.29114997214197 (0.01), AVG Score: -35.611355728012256
# Episode 149/500, Score: 266.9085964819759 (0.01), AVG Score: -32.01219134936826
# Episode 150/500, Score: 268.842083751162 (0.01), AVG Score: -27.046627549064116
# Episode 151/500, Score: 279.71170348263297 (0.01), AVG Score: -22.482111788605458
# Episode 152/500, Score: 4.18282393520926 (0.01), AVG Score: -20.715727777965512
# Episode 153/500, Score: 217.42626319467837 (0.01), AVG Score: -17.090919860916337
# Episode 154/500, Score: 260.97568444928083 (0.01), AVG Score: -11.985171839885679
# Episode 155/500, Score: 246.70956205040542 (0.01), AVG Score: -7.609592990261237
# Episode 156/500, Score: -362.52925049899216 (0.01), AVG Score: -9.529764084554474
# Episode 157/500, Score: -21.835107405343336 (0.01), AVG Score: -8.619068071820195
# Episode 158/500, Score: 300.13296054848195 (0.01), AVG Score: -4.692255613921843
# Episode 159/500, Score: 236.7849586228653 (0.01), AVG Score: -1.6912236529973648
# Episode 160/500, Score: 208.28878226609663 (0.01), AVG Score: 1.8278466601134817
# Episode 161/500, Score: 238.0114282212907 (0.01), AVG Score: 4.930445278999019
# Episode 162/500, Score: -373.82819488583937 (0.01), AVG Score: 1.7950671092113033
# Episode 163/500, Score: -63.74177675185523 (0.01), AVG Score: 1.5783007237286666
# Episode 164/500, Score: 77.65114162956667 (0.01), AVG Score: 2.4641527289265817
# Episode 165/500, Score: 268.7646060710992 (0.01), AVG Score: 5.069841055475772
# Episode 166/500, Score: 249.62469758614242 (0.01), AVG Score: 8.324400760522424
# Episode 167/500, Score: 220.38340791635923 (0.01), AVG Score: 11.154880469283482
# Episode 168/500, Score: 203.47166466901444 (0.01), AVG Score: 13.704700186346306
# Episode 169/500, Score: -107.03896690058492 (0.01), AVG Score: 13.16901093358927
# Episode 170/500, Score: -428.9236024397486 (0.01), AVG Score: 9.486174021665864
# Episode 171/500, Score: 258.16212130573274 (0.01), AVG Score: 12.270332035168485
# Episode 172/500, Score: 258.2806201563283 (0.01), AVG Score: 15.058084930398898
# Episode 173/500, Score: 244.3709590029546 (0.01), AVG Score: 17.582320828449905
# Episode 174/500, Score: 231.13505626569395 (0.01), AVG Score: 20.44586297108681
# Episode 175/500, Score: 231.51564520097673 (0.01), AVG Score: 23.553041045866557
# Episode 176/500, Score: 258.1122401589805 (0.01), AVG Score: 26.6083058314318
# Episode 177/500, Score: 213.70879880858 (0.01), AVG Score: 29.670648380289077
# Episode 178/500, Score: 245.93150622740086 (0.01), AVG Score: 34.074938971544846
# Episode 179/500, Score: 284.6620541921967 (0.01), AVG Score: 37.59793070475081
# Episode 180/500, Score: 258.5383962809858 (0.01), AVG Score: 40.51988123661466
# Episode 181/500, Score: 298.1692154412725 (0.01), AVG Score: 44.11996019152252
# Episode 182/500, Score: 257.42317470300804 (0.01), AVG Score: 48.273458378025204
# Episode 183/500, Score: 122.71788636762389 (0.01), AVG Score: 50.69370887998527
# Episode 184/500, Score: -268.5054659776622 (0.01), AVG Score: 49.15480649262945
# Episode 185/500, Score: 267.66276068378943 (0.01), AVG Score: 52.267548445624634
# Episode 186/500, Score: -59.24049339207566 (0.01), AVG Score: 52.2882555791525
# Episode 187/500, Score: 300.67697837989425 (0.01), AVG Score: 55.3795562233117
# Episode 188/500, Score: 208.45729762361256 (0.01), AVG Score: 58.05801723122664
# Episode 189/500, Score: 252.1681628721206 (0.01), AVG Score: 61.171910279887534
# Episode 190/500, Score: 217.2304099155252 (0.01), AVG Score: 63.979907402922244
# Episode 191/500, Score: 51.20743883375932 (0.01), AVG Score: 64.53836742974612
# Episode 192/500, Score: 206.2074669711396 (0.01), AVG Score: 66.61617262124564
# Episode 193/500, Score: 183.40923398362855 (0.01), AVG Score: 68.49653211744786
# Episode 194/500, Score: 187.7642277693621 (0.01), AVG Score: 71.9232610704528
# Episode 195/500, Score: 230.55030734663103 (0.01), AVG Score: 74.54158973255308
# Episode 196/500, Score: 283.3690750149858 (0.01), AVG Score: 80.09704309303068
# Episode 197/500, Score: 254.0731494383881 (0.01), AVG Score: 82.53332408898838
# Episode 198/500, Score: 196.56171162489903 (0.01), AVG Score: 84.29554716319943
# Episode 199/500, Score: 276.8825519215718 (0.01), AVG Score: 87.4436583464261
# Episode 200/500, Score: 236.70152708261466 (0.01), AVG Score: 90.25264731208601
# Episode 201/500, Score: 256.4359032177882 (0.01), AVG Score: 92.8356558501418
# Episode 202/500, Score: 236.3281076041633 (0.01), AVG Score: 95.13307126645226
# Episode 203/500, Score: 254.47070552997118 (0.01), AVG Score: 99.88831653124005
# Episode 204/500, Score: 254.67583195810775 (0.01), AVG Score: 103.020219905188
# Episode 205/500, Score: 264.0526190899816 (0.01), AVG Score: 106.42569607366005
# Episode 206/500, Score: -13.810153276523565 (0.01), AVG Score: 106.95995308624957
# Episode 207/500, Score: 281.92956631426966 (0.01), AVG Score: 110.00934315299348
# Episode 208/500, Score: 237.0288848539339 (0.01), AVG Score: 110.29917035956116
# Episode 209/500, Score: 256.6927855445474 (0.01), AVG Score: 113.46460239119995
# Episode 210/500, Score: 227.75039977869136 (0.01), AVG Score: 116.35353041818445
# Episode 211/500, Score: 242.60063472296406 (0.01), AVG Score: 119.69755704072507
# Episode 212/500, Score: 286.14805233480877 (0.01), AVG Score: 122.44439953253803
# Episode 213/500, Score: 241.91026024189594 (0.01), AVG Score: 124.94294253711072
# Episode 214/500, Score: -125.09752048220973 (0.01), AVG Score: 121.76017441331187
# Episode 215/500, Score: 219.41080551880694 (0.01), AVG Score: 122.08014220438214
# Episode 216/500, Score: 254.43649850370497 (0.01), AVG Score: 125.18585343565793
# Episode 217/500, Score: 35.029202250877546 (0.01), AVG Score: 126.18046166791535
# Episode 218/500, Score: 222.87628108337145 (0.01), AVG Score: 128.7444218112085
# Episode 219/500, Score: 262.0583436940723 (0.01), AVG Score: 131.92948683557316
# Episode 220/500, Score: 246.82374287280894 (0.01), AVG Score: 134.42927351981797
# Episode 221/500, Score: 293.63844962286834 (0.01), AVG Score: 137.86643067945312
# Episode 222/500, Score: 173.67315078973286 (0.01), AVG Score: 139.85864555514397
# Episode 223/500, Score: 283.0619601471451 (0.01), AVG Score: 143.0446948988488
# Episode 224/500, Score: -112.13720334770998 (0.01), AVG Score: 141.90025311462222
# Episode 225/500, Score: 241.23370082791865 (0.01), AVG Score: 144.25743609272132
# Episode 226/500, Score: 250.58662779376482 (0.01), AVG Score: 147.1216247049086
# Episode 227/500, Score: 316.2966999357333 (0.01), AVG Score: 150.50703046658862
# Episode 228/500, Score: 218.56731206881437 (0.01), AVG Score: 154.30533590161863
# Episode 229/500, Score: 268.4327641486704 (0.01), AVG Score: 157.66751927661267
# Episode 230/500, Score: 231.8688112369242 (0.01), AVG Score: 160.34065712904945
# Episode 231/500, Score: 292.35584325712523 (0.01), AVG Score: 163.38491158064116
# Episode 232/500, Score: 254.98351901853005 (0.01), AVG Score: 166.02560394784996
# Episode 233/500, Score: 252.5208382351708 (0.01), AVG Score: 168.55069462572567
# Episode 234/500, Score: -10.578560604529386 (0.01), AVG Score: 168.94866419434013
# Episode 235/500, Score: -99.18808182309012 (0.01), AVG Score: 169.12471104071895
# Episode 236/500, Score: 182.5438089550143 (0.01), AVG Score: 170.6713526682007
# Episode 237/500, Score: 265.05157329001236 (0.01), AVG Score: 173.2039414599429
# Episode 238/500, Score: 208.64826596523466 (0.01), AVG Score: 173.80699056733044
# Episode 239/500, Score: 267.7262489233698 (0.01), AVG Score: 174.1722497836596
# Episode 240/500, Score: 261.02122303132916 (0.01), AVG Score: 176.38500961325406
# Episode 241/500, Score: -112.6020725436795 (0.01), AVG Score: 173.11820746898857
# Episode 242/500, Score: 180.57586105400733 (0.01), AVG Score: 173.5729305617104
# Episode 243/500, Score: 267.44458924754593 (0.01), AVG Score: 177.37100178553032
# Episode 244/500, Score: 274.64898723404616 (0.01), AVG Score: 178.6417389471186
# Episode 245/500, Score: -43.40999047851142 (0.01), AVG Score: 178.3569260960772
# Episode 246/500, Score: 295.2711885407466 (0.01), AVG Score: 179.06339609574843
# Episode 247/500, Score: 249.0891010627907 (0.01), AVG Score: 179.11244197114968
# Episode 248/500, Score: 265.29999812764896 (0.01), AVG Score: 179.3625304527047
# Episode 249/500, Score: 250.9139380255213 (0.01), AVG Score: 179.20258386814018
# Episode 250/500, Score: 276.89559230769686 (0.01), AVG Score: 179.2831189537055
# Episode 251/500, Score: 257.11082761807467 (0.01), AVG Score: 179.05711019505995
# Episode 252/500, Score: 233.85560903291437 (0.01), AVG Score: 181.35383804603703
# Episode 253/500, Score: 287.40388017625867 (0.01), AVG Score: 182.05361421585275
# Episode 254/500, Score: 299.1325087112758 (0.01), AVG Score: 182.4351824584727
# Episode 255/500, Score: 233.59503112169529 (0.01), AVG Score: 182.3040371491856
# Episode 256/500, Score: 258.4620259441226 (0.01), AVG Score: 188.51394991361678
# Episode 257/500, Score: 283.34937011610873 (0.01), AVG Score: 191.5657946888313
# Episode 258/500, Score: 267.8147435518456 (0.01), AVG Score: 191.24261251886492
# Episode 259/500, Score: 256.28494201327374 (0.01), AVG Score: 191.43761235276898
# Episode 260/500, Score: 261.2131858058847 (0.01), AVG Score: 191.9668563881669
# Episode 261/500, Score: 271.3806729312927 (0.01), AVG Score: 192.30054883526688
# Episode 262/500, Score: 275.57640445314985 (0.01), AVG Score: 198.79459482865684
# Episode 263/500, Score: 17.745369524236608 (0.01), AVG Score: 199.60946629141773
# Episode 264/500, Score: 269.5730892449336 (0.01), AVG Score: 201.52868576757137
# WARNING:tensorflow:From C:\Users\stx6\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From C:\Users\stx6\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model0\assets
# Network saved
# Episode 265/500, Score: 252.74229012099494 (0.01), AVG Score: 201.36846260807033
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model1\assets
# Network saved
# Episode 266/500, Score: 250.79640129673916 (0.01), AVG Score: 201.3801796451763
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model2\assets
# Network saved
# Episode 267/500, Score: 230.67819200311126 (0.01), AVG Score: 201.48312748604383
# Episode 268/500, Score: 242.08121523543178 (0.01), AVG Score: 201.86922299170797
# Episode 269/500, Score: -0.4106942380227707 (0.01), AVG Score: 202.9355057183336
# Episode 270/500, Score: 246.70959405888328 (0.01), AVG Score: 209.6918376833199
# Episode 271/500, Score: 202.56455171388217 (0.01), AVG Score: 209.13586198740148
# Episode 272/500, Score: 266.5497079189171 (0.01), AVG Score: 209.2185528650274
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model3\assets
# Network saved
# Episode 273/500, Score: 297.3420843950239 (0.01), AVG Score: 209.74826411894807
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model4\assets
# Network saved
# Episode 274/500, Score: 274.2968240888552 (0.01), AVG Score: 210.17988179717966
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model5\assets
# Network saved
# Episode 275/500, Score: 261.1679231401745 (0.01), AVG Score: 210.47640457657167
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model6\assets
# Network saved
# Episode 276/500, Score: 282.96852579155507 (0.01), AVG Score: 210.7249674328974
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model7\assets
# Network saved
# Episode 277/500, Score: 249.1049889632131 (0.01), AVG Score: 211.07892933444376
# Episode 278/500, Score: 269.13596864220966 (0.01), AVG Score: 211.31097395859186
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model8\assets
# Network saved
# Episode 279/500, Score: 230.20337988004056 (0.01), AVG Score: 210.76638721547027
# Episode 280/500, Score: 276.8241257391925 (0.01), AVG Score: 210.9492445100523
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model9\assets
# Network saved
# Episode 281/500, Score: 259.53717743286825 (0.01), AVG Score: 210.56292412996828
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model10\assets
# Network saved
# Episode 282/500, Score: 282.71000111343056 (0.01), AVG Score: 210.81579239407247
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model11\assets
# Network saved
# Episode 283/500, Score: 271.45304370197454 (0.01), AVG Score: 212.303143967416
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model12\assets
# Network saved
# Episode 284/500, Score: 258.20511025597403 (0.01), AVG Score: 217.57024972975236
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model13\assets
# Network saved
# Episode 285/500, Score: 277.7463167876405 (0.01), AVG Score: 217.67108529079087
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model14\assets
# Network saved
# Episode 286/500, Score: 261.8629190623825 (0.01), AVG Score: 220.88211941533547
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model15\assets
# Network saved
# Episode 287/500, Score: 256.3792654751512 (0.01), AVG Score: 220.43914228628805
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model16\assets
# Network saved
# Episode 288/500, Score: 229.52221596727907 (0.01), AVG Score: 220.6497914697247
# Episode 289/500, Score: 242.73809793916726 (0.01), AVG Score: 220.55549082039514
# Episode 290/500, Score: 282.6650709590309 (0.01), AVG Score: 221.20983743083022
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model17\assets
# Network saved
# Episode 291/500, Score: 274.257244876686 (0.01), AVG Score: 223.4403354912595
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model18\assets
# Network saved
# Episode 292/500, Score: 244.1073720440726 (0.01), AVG Score: 223.81933454198884
# Episode 293/500, Score: 272.83483863325444 (0.01), AVG Score: 224.7135905884851
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model19\assets
# Network saved
# Episode 294/500, Score: 266.6915301691979 (0.01), AVG Score: 225.50286361248348
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model20\assets
# Network saved
# Episode 295/500, Score: 263.25357897423487 (0.01), AVG Score: 225.82989632875953
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model21\assets
# Network saved
# Episode 296/500, Score: 299.06191355402814 (0.01), AVG Score: 225.98682471414995
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model22\assets
# Network saved
# Episode 297/500, Score: 306.3695610959806 (0.01), AVG Score: 226.50978883072585
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model23\assets
# Network saved
# Episode 298/500, Score: 230.61321478884776 (0.01), AVG Score: 226.85030386236537
# Episode 299/500, Score: 272.14589766613403 (0.01), AVG Score: 226.80293731981095
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model24\assets
# Network saved
# Episode 300/500, Score: 276.19789161936865 (0.01), AVG Score: 227.1979009651785
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model25\assets
# Network saved
# Episode 301/500, Score: 275.3883963683668 (0.01), AVG Score: 227.38742589668425
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model26\assets
# Network saved
# Episode 302/500, Score: 233.98710827532244 (0.01), AVG Score: 227.36401590339585
# Episode 303/500, Score: 275.78469477938336 (0.01), AVG Score: 227.57715579589
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model27\assets
# Network saved
# Episode 304/500, Score: 249.9795525360726 (0.01), AVG Score: 227.5301930016696
# Episode 305/500, Score: 231.2270463937346 (0.01), AVG Score: 227.20193727470712
# Episode 306/500, Score: 174.61359822369513 (0.01), AVG Score: 229.08617478970933
# Episode 307/500, Score: 265.377509459188 (0.01), AVG Score: 228.92065422115851
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model28\assets
# Network saved
# Episode 308/500, Score: 40.908062636500176 (0.01), AVG Score: 226.95944599898417
# Episode 309/500, Score: 30.81412558621531 (0.01), AVG Score: 224.70065939940082
# Episode 310/500, Score: 255.85403471336576 (0.01), AVG Score: 224.9816957487476
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model29\assets
# Network saved
# Episode 311/500, Score: 23.855875667339646 (0.01), AVG Score: 222.79424815819138
# Episode 312/500, Score: 242.50545446178774 (0.01), AVG Score: 222.3578221794611
# Episode 313/500, Score: 275.404001660512 (0.01), AVG Score: 222.69275959364728
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model30\assets
# Network saved
# Episode 314/500, Score: 266.88346069592774 (0.01), AVG Score: 226.61256940542864
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model31\assets
# Network saved
# Episode 315/500, Score: 76.13337990534069 (0.01), AVG Score: 225.17979514929397
# Episode 316/500, Score: 255.25021679859637 (0.01), AVG Score: 225.1879323322429
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model32\assets
# Network saved
# Episode 317/500, Score: 284.20562484937545 (0.01), AVG Score: 227.67969655822787
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model33\assets
# Network saved
# Episode 318/500, Score: 281.4660131882911 (0.01), AVG Score: 228.26559387927708
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model34\assets
# Network saved
# Episode 319/500, Score: 263.427147518632 (0.01), AVG Score: 228.27928191752267
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model35\assets
# Network saved
# Episode 320/500, Score: 244.52676975105769 (0.01), AVG Score: 228.2563121863052
# Episode 321/500, Score: 288.9242693202149 (0.01), AVG Score: 228.20917038327866
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model36\assets
# Network saved
# Episode 322/500, Score: 285.0224909287338 (0.01), AVG Score: 229.32266378466866
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model37\assets
# Network saved
# Episode 323/500, Score: 250.06762334568865 (0.01), AVG Score: 228.9927204166541
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model38\assets
# Network saved
# Episode 324/500, Score: 277.9509827602162 (0.01), AVG Score: 232.89360227773332
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model39\assets
# Network saved
# Episode 325/500, Score: 1.189011190523189 (0.01), AVG Score: 230.4931553813594
# Episode 326/500, Score: 241.35192018317588 (0.01), AVG Score: 230.40080830525352
# Episode 327/500, Score: 282.2313074155403 (0.01), AVG Score: 230.06015438005159
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model40\assets
# Network saved
# Episode 328/500, Score: 234.8213790934407 (0.01), AVG Score: 230.2226950502979
# Episode 329/500, Score: 244.6889256430672 (0.01), AVG Score: 229.98525666524182
# Episode 330/500, Score: 257.23050675066787 (0.01), AVG Score: 230.23887362037928
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model41\assets
# Network saved
# Episode 331/500, Score: 180.58875208809275 (0.01), AVG Score: 229.12120270868894
# Episode 332/500, Score: 256.43445791517973 (0.01), AVG Score: 229.13571209765544
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model42\assets
# Network saved
# Episode 333/500, Score: 284.35957251370587 (0.01), AVG Score: 229.45409944044076
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model43\assets
# Network saved
# Episode 334/500, Score: 287.1628938272177 (0.01), AVG Score: 232.43151398475828
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model44\assets
# Network saved
# Episode 335/500, Score: 285.1763633761574 (0.01), AVG Score: 236.27515843675076
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model45\assets
# Network saved
# Episode 336/500, Score: 260.73728834834344 (0.01), AVG Score: 237.05709323068407
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model46\assets
# Network saved
# Episode 337/500, Score: 281.87327096951367 (0.01), AVG Score: 237.22531020747905
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model47\assets
# Network saved
# Episode 338/500, Score: -35.24220177458916 (0.01), AVG Score: 234.78640553008086
# Episode 339/500, Score: -54.09339448767245 (0.01), AVG Score: 231.5682090959704
# Episode 340/500, Score: 285.04660429651904 (0.01), AVG Score: 231.8084629086223
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model48\assets
# Network saved
# Episode 341/500, Score: 228.21710432105456 (0.01), AVG Score: 235.21665467726962
# Episode 342/500, Score: 279.57194284075456 (0.01), AVG Score: 236.20661549513707
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model49\assets
# Network saved
# Episode 343/500, Score: 16.849885408616515 (0.01), AVG Score: 233.70066845674782
# Episode 344/500, Score: 7.664853672308126 (0.01), AVG Score: 231.0308271211304
# Episode 345/500, Score: 251.68351494695472 (0.01), AVG Score: 233.98176217538506
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model50\assets
# Network saved
# Episode 346/500, Score: 47.58478889909253 (0.01), AVG Score: 231.50489817896855
# Episode 347/500, Score: 269.9222495365776 (0.01), AVG Score: 231.71322966370641
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model51\assets
# Network saved
# Episode 348/500, Score: 224.77345295273722 (0.01), AVG Score: 231.30796421195728
# Episode 349/500, Score: 268.50512511100396 (0.01), AVG Score: 231.48387608281212
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model52\assets
# Network saved
# Episode 350/500, Score: 289.1988270698648 (0.01), AVG Score: 231.6069084304338
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model53\assets
# Network saved
# Episode 351/500, Score: 255.4995379522336 (0.01), AVG Score: 231.59079553377535
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model54\assets
# Network saved
# Episode 352/500, Score: 231.45014879634707 (0.01), AVG Score: 231.56674093140967
# Episode 353/500, Score: 243.22101233803818 (0.01), AVG Score: 231.1249122530275
# Episode 354/500, Score: 246.64548292899653 (0.01), AVG Score: 230.6000419952047
# Episode 355/500, Score: 283.72948843483925 (0.01), AVG Score: 231.10138656833612
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model55\assets
# Network saved
# Episode 356/500, Score: 264.9765596984815 (0.01), AVG Score: 231.1665319058797
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model56\assets
# Network saved
# Episode 357/500, Score: 266.36169483712035 (0.01), AVG Score: 230.99665515308985
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model57\assets
# Network saved
# Episode 358/500, Score: 285.5620923560267 (0.01), AVG Score: 231.1741286411316
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model58\assets
# Network saved
# Episode 359/500, Score: 278.1565242225755 (0.01), AVG Score: 231.3928444632247
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model59\assets
# Network saved
# Episode 360/500, Score: 238.1481554029911 (0.01), AVG Score: 231.16219415919576
# Episode 361/500, Score: 253.71464149670066 (0.01), AVG Score: 230.9855338448498
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model60\assets
# Network saved
# Episode 362/500, Score: 276.66841254733515 (0.01), AVG Score: 230.99645392579168
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model61\assets
# Network saved
# Episode 363/500, Score: 283.4094114749784 (0.01), AVG Score: 233.6530943452991
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model62\assets
# Network saved
# Episode 364/500, Score: 293.3967193374764 (0.01), AVG Score: 233.89133064622453
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model63\assets
# Network saved
# Episode 365/500, Score: 274.27085204820526 (0.01), AVG Score: 234.10661626549663
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model64\assets
# Network saved
# Episode 366/500, Score: 278.81887789768405 (0.01), AVG Score: 234.3868410315061
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model65\assets
# Network saved
# Episode 367/500, Score: 282.24291801575123 (0.01), AVG Score: 234.90248829163247
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model66\assets
# Network saved
# Episode 368/500, Score: 315.2909199160645 (0.01), AVG Score: 235.6345853384388
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model67\assets
# Network saved
# Episode 369/500, Score: 280.60927173176117 (0.01), AVG Score: 238.44478499813667
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model68\assets
# Network saved
# Episode 370/500, Score: 274.81655435202543 (0.01), AVG Score: 238.7258546010681
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model69\assets
# Network saved
# Episode 371/500, Score: 252.05711990626367 (0.01), AVG Score: 239.2207802829919
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model70\assets
# Network saved
# Episode 372/500, Score: 299.811343756658 (0.01), AVG Score: 239.5533966413693
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model71\assets
# Network saved
# Episode 373/500, Score: 315.11137698510606 (0.01), AVG Score: 239.73108956727015
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model72\assets
# Network saved
# Episode 374/500, Score: 262.57189476531255 (0.01), AVG Score: 239.61384027403466
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model73\assets
# Network saved
# Episode 375/500, Score: 270.19441508826696 (0.01), AVG Score: 239.70410519351557
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model74\assets
# Network saved
# Episode 376/500, Score: 250.71864013734734 (0.01), AVG Score: 239.3816063369735
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model75\assets
# Network saved
# Episode 377/500, Score: 261.73019481841493 (0.01), AVG Score: 239.50785839552552
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model76\assets
# Network saved
# Episode 378/500, Score: 268.2297805745608 (0.01), AVG Score: 239.498796514849
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model77\assets
# Network saved
# Episode 379/500, Score: 263.69129495224865 (0.01), AVG Score: 239.83367566557115
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model78\assets
# Network saved
# Episode 380/500, Score: 294.5889522443785 (0.01), AVG Score: 240.011323930623
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model79\assets
# Network saved
# Episode 381/500, Score: 283.64067700241003 (0.01), AVG Score: 240.2523589263184
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model80\assets
# Network saved
# Episode 382/500, Score: 291.858101587519 (0.01), AVG Score: 240.3438399310593
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model81\assets
# Network saved
# Episode 383/500, Score: 273.1803097134772 (0.01), AVG Score: 240.36111259117436
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model82\assets
# Network saved
# Episode 384/500, Score: 237.78722718578442 (0.01), AVG Score: 240.15693376047247
# Episode 385/500, Score: 262.1750051235422 (0.01), AVG Score: 240.00122064383143
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model83\assets
# Network saved
# Episode 386/500, Score: 268.3058031518235 (0.01), AVG Score: 240.06564948472587
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model84\assets
# Network saved
# Episode 387/500, Score: 268.25260536422536 (0.01), AVG Score: 240.1843828836166
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model85\assets
# Network saved
# Episode 388/500, Score: 235.1800496429766 (0.01), AVG Score: 240.24096122037358
# Episode 389/500, Score: 263.911957546841 (0.01), AVG Score: 240.4526998164503
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model86\assets
# Network saved
# Episode 390/500, Score: 273.7928462750368 (0.01), AVG Score: 240.3639775696103
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model87\assets
# Network saved
# Episode 391/500, Score: 237.19287920667986 (0.01), AVG Score: 239.99333391291023
# Episode 392/500, Score: 277.8697038905809 (0.01), AVG Score: 240.33095723137535
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model88\assets
# Network saved
# Episode 393/500, Score: 14.992359087507651 (0.01), AVG Score: 237.75253243591789
# Episode 394/500, Score: 247.82839827727503 (0.01), AVG Score: 237.56390111699866
# Episode 395/500, Score: 280.3586524765759 (0.01), AVG Score: 237.73495185202205
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model89\assets
# Network saved
# Episode 396/500, Score: 254.42914353669389 (0.01), AVG Score: 237.2886241518487
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model90\assets
# Network saved
# Episode 397/500, Score: 275.53023426231414 (0.01), AVG Score: 236.98023088351204
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model91\assets
# Network saved
# Episode 398/500, Score: 266.5737305163026 (0.01), AVG Score: 237.33983604078662
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model92\assets
# Network saved
# Episode 399/500, Score: 255.68227292684418 (0.01), AVG Score: 237.1751997933937
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model93\assets
# Network saved
# Episode 400/500, Score: 281.56456652508217 (0.01), AVG Score: 237.22886654245085
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model94\assets
# Network saved
# Episode 401/500, Score: 271.91545683523543 (0.01), AVG Score: 237.19413714711953
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model95\assets
# Network saved
# Episode 402/500, Score: 290.87676595880214 (0.01), AVG Score: 237.76303372395432
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model96\assets
# Network saved
# Episode 403/500, Score: 252.7247179237648 (0.01), AVG Score: 237.53243395539815
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model97\assets
# Network saved
# Episode 404/500, Score: 259.3016764880011 (0.01), AVG Score: 237.62565519491744
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model98\assets
# Network saved
# Episode 405/500, Score: 287.88820306458393 (0.01), AVG Score: 238.19226676162594
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model99\assets
# Network saved
# Episode 406/500, Score: 254.9608758946075 (0.01), AVG Score: 238.99573953833507
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model100\assets
# Network saved
# Episode 407/500, Score: 256.27324234890557 (0.01), AVG Score: 238.9046968672323
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model101\assets
# Network saved
# Episode 408/500, Score: 238.12038086770266 (0.01), AVG Score: 240.8768200495443
# Episode 409/500, Score: 266.70974137094953 (0.01), AVG Score: 243.23577620739164
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model102\assets
# Network saved
# Episode 410/500, Score: 264.5629781220723 (0.01), AVG Score: 243.3228656414787
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model103\assets
# Network saved
# Episode 411/500, Score: 254.88816730423878 (0.01), AVG Score: 245.63318855784763
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model104\assets
# Network saved
# Episode 412/500, Score: 247.72982168262297 (0.01), AVG Score: 245.685432230056
# Episode 413/500, Score: 232.71242474201736 (0.01), AVG Score: 245.2585164608711
# Episode 414/500, Score: 288.75517808017116 (0.01), AVG Score: 245.4772336347135
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model105\assets
# Network saved
# Episode 415/500, Score: 252.10818182284717 (0.01), AVG Score: 247.23698165388862
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model106\assets
# Network saved
# Episode 416/500, Score: 266.9629447834418 (0.01), AVG Score: 247.35410893373705
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model107\assets
# Network saved
# Episode 417/500, Score: 221.71613882653216 (0.01), AVG Score: 246.7292140735086
# Episode 418/500, Score: 286.1694508432618 (0.01), AVG Score: 246.7762484500583
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model108\assets
# Network saved
# Episode 419/500, Score: 265.4929195485927 (0.01), AVG Score: 246.79690617035791
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model109\assets
# Network saved
# Episode 420/500, Score: 272.0302537052686 (0.01), AVG Score: 247.0719410099001
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model110\assets
# Network saved
# Episode 421/500, Score: 275.57028393877863 (0.01), AVG Score: 246.93840115608566
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model111\assets
# Network saved
# Episode 422/500, Score: 303.87954930953595 (0.01), AVG Score: 247.12697173989366
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model112\assets
# Network saved
# Episode 423/500, Score: 276.531606566468 (0.01), AVG Score: 247.39161157210145
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model113\assets
# Network saved
# Episode 424/500, Score: 259.5668606090678 (0.01), AVG Score: 247.20777035059
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model114\assets
# Network saved
# Episode 425/500, Score: 288.4176628676843 (0.01), AVG Score: 250.08005686736158
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model115\assets
# Network saved
# Episode 426/500, Score: 280.6543533962183 (0.01), AVG Score: 250.47308119949201
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model116\assets
# Network saved
# Episode 427/500, Score: 293.9330930144323 (0.01), AVG Score: 250.59009905548098
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model117\assets
# Network saved
# Episode 428/500, Score: 265.7699927719151 (0.01), AVG Score: 250.89958519226565
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model118\assets
# Network saved
# Episode 429/500, Score: 290.00759839458215 (0.01), AVG Score: 251.3527719197808
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model119\assets
# Network saved
# Episode 430/500, Score: 305.6649427092696 (0.01), AVG Score: 251.83711627936685
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model120\assets
# Network saved
# Episode 431/500, Score: 273.27777137943065 (0.01), AVG Score: 252.76400647228024
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model121\assets
# Network saved
# Episode 432/500, Score: 250.84264906859065 (0.01), AVG Score: 252.70808838381436
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model122\assets
# Network saved
# Episode 433/500, Score: 315.01188624979693 (0.01), AVG Score: 253.0146115211753
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model123\assets
# Network saved
# Episode 434/500, Score: 244.10052913369537 (0.01), AVG Score: 252.58398787424008
# Episode 435/500, Score: 270.2172287142807 (0.01), AVG Score: 252.4343965276213
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model124\assets
# Network saved
# Episode 436/500, Score: 269.54473127552365 (0.01), AVG Score: 252.52247095689307
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model125\assets
# Network saved
# Episode 437/500, Score: 303.34818247501175 (0.01), AVG Score: 252.73722007194806
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model126\assets
# Network saved
# Episode 438/500, Score: 255.84289720475414 (0.01), AVG Score: 255.64807106174155
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model127\assets
# Network saved
# Episode 439/500, Score: 312.52032343117037 (0.01), AVG Score: 259.31420824092993
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model128\assets
# Network saved
# Episode 440/500, Score: 271.9242753244439 (0.01), AVG Score: 259.18298495120916
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model129\assets
# Network saved
# Episode 441/500, Score: 278.73583507327805 (0.01), AVG Score: 259.6881722587314
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model130\assets
# Network saved
# Episode 442/500, Score: 246.59405727526416 (0.01), AVG Score: 259.3583934030765
# Episode 443/500, Score: 302.1328215069408 (0.01), AVG Score: 262.2112227640597
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model131\assets
# Network saved
# Episode 444/500, Score: 274.4549757379099 (0.01), AVG Score: 264.87912398471576
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model132\assets
# Network saved
# Episode 445/500, Score: 235.45216873370208 (0.01), AVG Score: 264.7168105225832
# Episode 446/500, Score: 303.21676824337214 (0.01), AVG Score: 267.273130316026
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model133\assets
# Network saved
# Episode 447/500, Score: 259.65229791998354 (0.01), AVG Score: 267.1704307998601
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model134\assets
# Network saved
# Episode 448/500, Score: 235.56634063001428 (0.01), AVG Score: 267.2783596766329
# Episode 449/500, Score: 65.48339397328732 (0.01), AVG Score: 265.2481423652557
# Episode 450/500, Score: 222.16562555773825 (0.01), AVG Score: 264.5778103501345
# Episode 451/500, Score: 265.2853569936635 (0.01), AVG Score: 264.67566854054877
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model135\assets
# Network saved
# Episode 452/500, Score: 250.75039398766953 (0.01), AVG Score: 264.86867099246194
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model136\assets
# Network saved
# Episode 453/500, Score: 291.4242268650438 (0.01), AVG Score: 265.350703137732
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model137\assets
# Network saved
# Episode 454/500, Score: 267.98085025972085 (0.01), AVG Score: 265.5640568110393
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model138\assets
# Network saved
# Episode 455/500, Score: 281.0510601745124 (0.01), AVG Score: 265.537272528436
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model139\assets
# Network saved
# Episode 456/500, Score: 269.76139464837445 (0.01), AVG Score: 265.5851208779349
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model140\assets
# Network saved
# Episode 457/500, Score: 271.7973742861902 (0.01), AVG Score: 265.63947767242564
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model141\assets
# Network saved
# Episode 458/500, Score: 255.09917186167192 (0.01), AVG Score: 265.33484846748206
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model142\assets
# Network saved
# Episode 459/500, Score: 288.5284089596097 (0.01), AVG Score: 265.43856731485243
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model143\assets
# Network saved
# Episode 460/500, Score: 302.6680508329418 (0.01), AVG Score: 266.0837662691519
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model144\assets
# Network saved
# Episode 461/500, Score: 256.4780586837279 (0.01), AVG Score: 266.11140044102217
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model145\assets
# Network saved
# Episode 462/500, Score: 243.4495648631747 (0.01), AVG Score: 265.7792119641806
# Episode 463/500, Score: 276.2722388717881 (0.01), AVG Score: 265.70784023814866
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model146\assets
# Network saved
# Episode 464/500, Score: 234.71881217728136 (0.01), AVG Score: 265.1210611665467
# Episode 465/500, Score: 270.4573006738778 (0.01), AVG Score: 265.08292565280345
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model147\assets
# Network saved
# Episode 466/500, Score: -28.331006798654585 (0.01), AVG Score: 262.0114268058401
# Episode 467/500, Score: 300.39177715391696 (0.01), AVG Score: 262.1929153972217
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model148\assets
# Network saved
# Episode 468/500, Score: 249.38663678557614 (0.01), AVG Score: 261.53387256591685
# Episode 469/500, Score: 304.4906944221107 (0.01), AVG Score: 261.77268679282037
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model149\assets
# Network saved
# Episode 470/500, Score: 251.82352613940063 (0.01), AVG Score: 261.54275651069406
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model150\assets
# Network saved
# Episode 471/500, Score: 257.0720608261784 (0.01), AVG Score: 261.5929059198932
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model151\assets
# Network saved
# Episode 472/500, Score: 259.4393137791882 (0.01), AVG Score: 261.18918562011856
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model152\assets
# Network saved
# Episode 473/500, Score: 275.73768296749455 (0.01), AVG Score: 260.7954486799424
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model153\assets
# Network saved
# Episode 474/500, Score: 228.50885510468868 (0.01), AVG Score: 260.4548182833362
# Episode 475/500, Score: 273.6450978109907 (0.01), AVG Score: 260.4893251105634
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model154\assets
# Network saved
# Episode 476/500, Score: -230.98662650091447 (0.01), AVG Score: 255.67227244418078
# Episode 477/500, Score: 244.5954089955308 (0.01), AVG Score: 255.50092458595194
# Episode 478/500, Score: 263.22589754998546 (0.01), AVG Score: 255.45088575570614
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model155\assets
# Network saved
# Episode 479/500, Score: 304.24854773429985 (0.01), AVG Score: 255.8564582835267
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model156\assets
# Network saved
# Episode 480/500, Score: -377.2756074513679 (0.01), AVG Score: 249.13781268656928
# Episode 481/500, Score: 251.262279538075 (0.01), AVG Score: 248.81402871192589
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model157\assets
# Network saved
# Episode 482/500, Score: 275.32570046378333 (0.01), AVG Score: 248.6487047006885
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model158\assets
# Network saved
# Episode 483/500, Score: 287.87931248893483 (0.01), AVG Score: 248.7956947284431
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model159\assets
# Network saved
# Episode 484/500, Score: 252.87065948839893 (0.01), AVG Score: 248.9465290514692
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model160\assets
# Network saved
# Episode 485/500, Score: 302.25201601579056 (0.01), AVG Score: 249.3472991603917
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model161\assets
# Network saved
# Episode 486/500, Score: 290.01404025149907 (0.01), AVG Score: 249.5643815313885
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model162\assets
# Network saved
# Episode 487/500, Score: 286.37740844561495 (0.01), AVG Score: 249.74562956220242
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model163\assets
# Network saved
# Episode 488/500, Score: -12.415557885020021 (0.01), AVG Score: 247.26967348692244
# Episode 489/500, Score: 292.29228634670284 (0.01), AVG Score: 247.55347677492108
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model164\assets
# Network saved
# Episode 490/500, Score: 268.6721216864501 (0.01), AVG Score: 247.50226952903517
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model165\assets
# Network saved
# Episode 491/500, Score: 241.6534434245026 (0.01), AVG Score: 247.54687517121343
# Episode 492/500, Score: 278.7232019836671 (0.01), AVG Score: 247.55541015214425
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model166\assets
# Network saved
# Episode 493/500, Score: 267.7016320505672 (0.01), AVG Score: 250.08250288177484
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model167\assets
# Network saved
# Episode 494/500, Score: 262.5565434528324 (0.01), AVG Score: 250.22978433353043
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model168\assets
# Network saved
# Episode 495/500, Score: 237.14999263838192 (0.01), AVG Score: 249.79769773514846
# Episode 496/500, Score: 159.84186977867296 (0.01), AVG Score: 248.85182499756826
# Episode 497/500, Score: -203.084403221015 (0.01), AVG Score: 244.065678622735
# Episode 498/500, Score: 278.5701983677724 (0.01), AVG Score: 244.18564330124966
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model169\assets
# Network saved
# Episode 499/500, Score: 276.4334541407312 (0.01), AVG Score: 244.39315511338853
# INFO:tensorflow:Assets written to: saved_networks/d3qn_model170\assets
# Network saved
